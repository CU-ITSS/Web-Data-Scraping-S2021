# %% [markdown]
# # Web Data Scraping
#
# [Spring 2019 ITSS Mini-Course](https://www.colorado.edu/cartss/programs/interdisciplinary-training-social-sciences-itss/mini-course-web-data-scraping) — ARSC 5040
# [Brian C. Keegan, Ph.D.](http://brianckeegan.com/)
# [Assistant Professor, Department of Information Science](https://www.colorado.edu/cmci/people/information-science/brian-c-keegan)
# University of Colorado Boulder
#
# Copyright and distributed under an [MIT License](https://opensource.org/licenses/MIT)
#
# ## Class outline
#
# * **Week 1**: Introduction to Jupyter, browser console, structured data, ethical considerations
# * **Week 2**: Scraping HTML with `requests` and `BeautifulSoup`
# * **Week 3**: Scraping web data with Selenium
# * **Week 4**: Scraping an API with `requests` and `json`, Wikipedia and Reddit
# * **Week 5**: Scraping data from Twitter
#
# ## Acknowledgements
#
# Thank you also to Professors [Bhuvana Narasimhan](https://www.colorado.edu/linguistics/bhuvana-narasimhan) and [Stefanie Mollborn](https://behavioralscience.colorado.edu/person/stefanie-mollborn) for coordinating the ITSS seminars.
#
# ## Class 5 goals
#
# * Sharing accomplishments and challenges with last week's material
# * Using the `python-twitter` wrapper library to handle authentication
# * Retrieving and parsing a single tweet
# * Rehydrating a list of tweet IDs
# * Pulling a user's timeline
# * Pulling a user's friend and follower lists
# * Using the search endpoint of the API
# * Listen to the streaming API
# * Detecting bot accounts using IU's Bot-o-Meter
#
# Start with our usual suspect packages.

# %%
# Lets Jupyter Notebook display images in-line
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# Import our helper libraries
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import json
import requests
from bs4 import BeautifulSoup
import time
from urllib.parse import quote, unquote

# Import the VADER sentiment analyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Instantiate the model
sia = SentimentIntensityAnalyzer()
# Out:
# /Users/briankeegan/anaconda/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# ## Installing a Twitter API wrapper
#
# As was the case with Reddit, we will take advantage of a wrapper library to handle the heavy lifting of authenticating, making specific requests, handling rate-limiting, *etc*. There are no shortage of Python wrappers for the Twitter API, but the most popular are:
#
# * [python-twitter](https://python-twitter.readthedocs.io/en/latest/)
# * [Tweepy](http://docs.tweepy.org/en/latest/)
# * [Twython](https://twython.readthedocs.io/en/latest/)
#
# There are other wrapper libraries linked from the [Twitter developer utilities documentation](https://developer.twitter.com/en/docs/developer-utilities/twitter-libraries.html).
#
# I'm going to use `python-twitter` just because it's more lightweight, but the glaring lack of examples and tutorials in the documentation is disappointing.
#
# You will need to install this since it does not come with conda by default. At the Terminal:
#
# `pip install python-twitter`
#
# Once you've installed it, you can import the `twitter` wrapper library.

# %%
import twitter

# %% [markdown]
# ## Authenticating
# I don't want to share my Twitter credentials with the world, so I load from from my local machine. If you wanted to do this, it should take this format of:
#
# ```
# {"consumer_key":"API key",
#  "consumer_secret":"API secret key",
#  "access_token_key":"Access token",
#  "access_token_secret":"Access token secret"
# }
# ```

# %%
# Load my key information from disk
with open('twitter_keys.json','r') as f:
    twitter_keys = json.load(f)

# Authenticate with the Twitter API using the twitter_keys dictionary
# The "tweet_mode='extended' allows us to see the full 280 characters in tweets
api = twitter.Api(**twitter_keys,tweet_mode='extended')

# %% [markdown]
# Alternatively, you can just enter your keys directly into the `Api` function.

# %%
api = twitter.Api(consumer_key = 'API key',
                  consumer_secret = 'API secret key',
                  access_token_key = 'Access token',
                  access_token_secret = 'Access token secret',
                  tweet_mode='extended')

# %% [markdown]
# Test that you can connect to the API.

# %%
api.GetUser(screen_name='realdonaldtrump')
# Out:
# User(ID=25073877, ScreenName=realDonaldTrump)

# %% [markdown]
# ## Getting the payload of a single tweet
#
# Wikipedia helpfully maintains a [List of most-retweeted tweets](https://en.wikipedia.org/wiki/List_of_most-retweeted_tweets). Go to one of the tweets and pull out the ID at the end of the URL.

# %%
tweet = api.GetStatus('849813577770778624')

# %%
vars(tweet)
# Out:
# {'param_defaults': {'contributors': None,
#   'coordinates': None,
#   'created_at': None,
#   'current_user_retweet': None,
#   'favorite_count': None,
#   'favorited': None,
#   'full_text': None,
#   'geo': None,
#   'hashtags': None,
#   'id': None,
#   'id_str': None,
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_user_id': None,
#   'lang': None,
#   'location': None,
#   'media': None,
#   'place': None,
#   'possibly_sensitive': None,
#   'quoted_status': None,
#   'quoted_status_id': None,
#   'quoted_status_id_str': None,
#   'retweet_count': None,
#   'retweeted': None,
#   'retweeted_status': None,
#   'scopes': None,
#   'source': None,
#   'text': None,
#   'truncated': None,
#   'urls': None,
#   'user': None,
#   'user_mentions': None,
#   'withheld_copyright': None,
#   'withheld_in_countries': None,
#   'withheld_scope': None},
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Apr 06 02:38:40 +0000 2017',
#  'current_user_retweet': None,
#  'favorite_count': 988543,
#  'favorited': False,
#  'full_text': 'HELP ME PLEASE. A MAN NEEDS HIS NUGGS https://t.co/4SrfHmEMo3',
#  'geo': None,
#  'hashtags': [],
#  'id': 849813577770778624,
#  'id_str': '849813577770778624',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_user_id': None,
#  'lang': 'en',
#  'location': None,
#  'media': [Media(ID=849813572351737856, Type=photo, DisplayURL='pic.twitter.com/4SrfHmEMo3')],
#  'place': None,
#  'possibly_sensitive': False,
#  'quoted_status': None,
#  'quoted_status_id': None,
#  'quoted_status_id_str': None,
#  'retweet_count': 3536229,
#  'retweeted': False,
#  'retweeted_status': None,
#  'scopes': None,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': None,
#  'truncated': False,
#  'urls': [],
#  'user': User(ID=2568270758, ScreenName=carterjwm),
#  'user_mentions': [],
#  'withheld_copyright': None,
#  'withheld_in_countries': None,
#  'withheld_scope': None,
#  'tweet_mode': 'extended',
#  '_json': {'created_at': 'Thu Apr 06 02:38:40 +0000 2017',
#   'id': 849813577770778624,
#   'id_str': '849813577770778624',
#   'full_text': 'HELP ME PLEASE. A MAN NEEDS HIS NUGGS https://t.co/4SrfHmEMo3',
#   'truncated': False,
#   'display_text_range': [0, 37],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 849813572351737856,
#      'id_str': '849813572351737856',
#      'indices': [38, 61],
#      'media_url': 'http://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg',
#      'url': 'https://t.co/4SrfHmEMo3',
#      'display_url': 'pic.twitter.com/4SrfHmEMo3',
#      'expanded_url': 'https://twitter.com/carterjwm/status/849813577770778624/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 382, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 750, 'h': 1334, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 849813572351737856,
#      'id_str': '849813572351737856',
#      'indices': [38, 61],
#      'media_url': 'http://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg',
#      'url': 'https://t.co/4SrfHmEMo3',
#      'display_url': 'pic.twitter.com/4SrfHmEMo3',
#      'expanded_url': 'https://twitter.com/carterjwm/status/849813577770778624/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 382, 'h': 680, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'large': {'w': 750, 'h': 1334, 'resize': 'fit'}},
#      'ext_alt_text': None}]},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2568270758,
#    'id_str': '2568270758',
#    'name': 'Carter Wilkerson',
#    'screen_name': 'carterjwm',
#    'location': 'Reno, NV - San Diego, CA',
#    'description': 'I kinda like chicken nuggets',
#    'url': 'https://t.co/hEJZpy9pwS',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/hEJZpy9pwS',
#        'expanded_url': 'http://nuggsforcarter.com',
#        'display_url': 'nuggsforcarter.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 100327,
#    'friends_count': 287,
#    'listed_count': 3169,
#    'created_at': 'Sun Jun 15 03:48:03 +0000 2014',
#    'favourites_count': 27392,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 1723,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1049068688387727360/ZVPaPtll_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1049068688387727360/ZVPaPtll_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2568270758/1536506952',
#    'profile_image_extensions_alt_text': None,
#    'profile_banner_extensions_alt_text': None,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3536229,
#   'favorite_count': 988543,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}}

# %% [markdown]
# This returns a `Status` object. If we want the raw data inside this `Status` object, we can use the `.AsDict()` function.

# %%
tweet.AsDict()
# Out:
# {'created_at': 'Thu Apr 06 02:38:40 +0000 2017',
#  'favorite_count': 988543,
#  'full_text': 'HELP ME PLEASE. A MAN NEEDS HIS NUGGS https://t.co/4SrfHmEMo3',
#  'hashtags': [],
#  'id': 849813577770778624,
#  'id_str': '849813577770778624',
#  'lang': 'en',
#  'media': [{'display_url': 'pic.twitter.com/4SrfHmEMo3',
#    'expanded_url': 'https://twitter.com/carterjwm/status/849813577770778624/photo/1',
#    'id': 849813572351737856,
#    'media_url': 'http://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg',
#    'media_url_https': 'https://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg',
#    'sizes': {'small': {'w': 382, 'h': 680, 'resize': 'fit'},
#     'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#     'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#     'large': {'w': 750, 'h': 1334, 'resize': 'fit'}},
#    'type': 'photo',
#    'url': 'https://t.co/4SrfHmEMo3'}],
#  'retweet_count': 3536229,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'urls': [],
#  'user': {'created_at': 'Sun Jun 15 03:48:03 +0000 2014',
#   'default_profile': True,
#   'description': 'I kinda like chicken nuggets',
#   'favourites_count': 27392,
#   'followers_count': 100327,
#   'friends_count': 287,
#   'geo_enabled': True,
#   'id': 2568270758,
#   'id_str': '2568270758',
#   'lang': 'en',
#   'listed_count': 3169,
#   'location': 'Reno, NV - San Diego, CA',
#   'name': 'Carter Wilkerson',
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2568270758/1536506952',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1049068688387727360/ZVPaPtll_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1049068688387727360/ZVPaPtll_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'screen_name': 'carterjwm',
#   'statuses_count': 1723,
#   'url': 'https://t.co/hEJZpy9pwS',
#   'verified': True},
#  'user_mentions': []}

# %% [markdown]
# There are other attributes we can access directly from the object rather than having to navigate the JSON structure. Your ability to access these attributes is a function of the `python-twitter` library rather than the raw data returned by the Twitter API, so I would prefer to work with the JSON in the interests of forward compatibility, but you do you. Here's how to access via the attributes of a `Status` object returned by `python-twitter`.

# %%
# When was the tweet created?
tweet.created_at
# Out:
# 'Thu Apr 06 02:38:40 +0000 2017'

# %%
tweet.AsDict()['created_at']
# Out:
# 'Thu Apr 06 02:38:40 +0000 2017'

# %%
# Number of favorites (at the time of the API call)
tweet.favorite_count
# Out:
# 988543

# %%
tweet.AsDict()['favorite_count']
# Out:
# 988543

# %%
# Number of retweets (at the time of the API call)
tweet.retweet_count
# Out:
# 3536229

# %%
tweet.AsDict()['retweet_count']
# Out:
# 3536229

# %%
# Text of the tweet
tweet.full_text
# Out:
# 'HELP ME PLEASE. A MAN NEEDS HIS NUGGS https://t.co/4SrfHmEMo3'

# %%
tweet.AsDict()['full_text']
# Out:
# 'HELP ME PLEASE. A MAN NEEDS HIS NUGGS https://t.co/4SrfHmEMo3'

# %%
# Location (if it geo-located)
tweet.geo

# %%
# List of hashtags present
tweet.hashtags
# Out:
# []

# %%
# Tweet ID
tweet.id
# Out:
# 849813577770778624

# %%
tweet.AsDict()['id']
# Out:
# 849813577770778624

# %%
# A guess at the language of the tweet
tweet.lang
# Out:
# 'en'

# %% [markdown]
# These next two attributes return `User` and `Media` objects rather than simple strings, ints, *etc*. that have their own attributes and methods.

# %%
tweet.user
# Out:
# User(ID=2568270758, ScreenName=carterjwm)

# %% [markdown]
# We can access attributes of this `User` object.

# %%
# Screen name of the user
tweet.user.screen_name
# Out:
# 'carterjwm'

# %%
tweet.AsDict()['user']['screen_name']
# Out:
# 'carterjwm'

# %%
# Displayed name of the user
tweet.user.name
# Out:
# 'Carter Wilkerson'

# %%
# User biography
tweet.user.description
# Out:
# 'I kinda like chicken nuggets'

# %%
# Account creation time
tweet.user.created_at
# Out:
# 'Sun Jun 15 03:48:03 +0000 2014'

# %%
tweet.AsDict()['user']['created_at']
# Out:
# 'Sun Jun 15 03:48:03 +0000 2014'

# %%
# Self-reported location
tweet.user.location
# Out:
# 'Reno, NV - San Diego, CA'

# %%
# Number of tweets from the user
tweet.user.statuses_count
# Out:
# 1723

# %%
# Number of followers
tweet.user.followers_count
# Out:
# 100327

# %%
# Number of friends (accounts this account follows, followees, etc.)
tweet.user.friends_count
# Out:
# 287

# %% [markdown]
# Similarly, the `Media` object inside this list contains information about the type and the URLs of the media inside this object. If there were multiple images in this tweet, there would be a `Media` item in the list for each of them.

# %%
tweet.media[0].type
# Out:
# 'photo'

# %%
tweet.media[0].media_url
# Out:
# 'http://pbs.twimg.com/media/C8sk8QlUwAAR3qI.jpg'

# %% [markdown]
# ## Rehydrating a list of tweets
#
# Twitter's Terms of Service do not allow datasets of statuses to be shared, but researchers are permitted to share the identifiers for tweets in their datasets. Researchers then need to "rehydrate" these statuses by requesting the full payloads from Twitter's API. A list of resources with links to tweet IDs used in research:
#
# * [DocNow's Tweet ID Datasets](https://www.docnow.io/catalog/)
# * [FollowTheHashtag's Free Twitter Datasets](http://followthehashtag.com/datasets/)
# * [AcademicTorrents](http://academictorrents.com/browse.php?search=twitter)
# * [FiveThirtyEight's Russian Troll Tweets](https://github.com/fivethirtyeight/russian-troll-tweets/)
# * [Harvard Dataverse](https://dataverse.harvard.edu/dataverse/harvard?q=twitter&types=datasets&sort=score&order=desc&page=1)
#
# This has some privacy benefits: Twitter's [compliance statement](https://developer.twitter.com/en/docs/tweets/compliance/overview) describes that users should retain the option to delete tweets or their accounts and this rehydration arrangement—theoretically—prevents their tweet content from circulating without their consent. In practice, many of the largest Twitter corpora come from the streaming API (more on that later in this notebook) and Twitter has a "[compliance stream](https://developer.twitter.com/en/docs/tweets/compliance/api-reference/compliance-firehose)" that indicates that a user has deleted a tweet, protected their account, Twitter has suspended an account, Twitter has withheld the status, *etc*. and the tweet should be removed from your streaming dataset as well. The Sunlight Foundation and ProPublica maintain a list of deleted tweets from politicians called [Politiwoops](https://projects.propublica.org/politwoops/).
#
# I am going to use a [list of tweets made by Senators in the 115th Congress](https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/UIVHQR) collected by Justin Littman in 2017. Load the text file:

# %%
with open('senators-115th.txt','r') as f:
    senators_tweet_ids = [tweet_id.strip() for tweet_id in f.readlines()]
    
"There are {0:,} tweets IDs in the file.".format(len(senators_tweet_ids))
# Out:
# 'There are 519,210 tweets IDs in the file.'

# %% [markdown]
# Look at the first 10 statuses.

# %%
senators_tweet_ids[:10]
# Out:
# ['942793432321462273',
#  '942513647695351808',
#  '942439827970183169',
#  '942419102597107713',
#  '942419087833092096',
#  '942403862673215488',
#  '942402966673395713',
#  '942402245991260160',
#  '942401802628104197',
#  '942399780008923138']

# %% [markdown]
# Use the `GetStatuses` function, which accepts a dictionary of status IDs in order to hydrate this list of tweets. We will use the "`map=True`" parameter to keep track of any tweets that were not returned (which should be `None`s rather than `Status`es).
#
# Now for a bit of accounting on rate limits. According to the API documentation for [get statuses/lookup](https://developer.twitter.com/en/docs/tweets/post-and-engage/api-reference/get-statuses-lookup), you can ask for up to 100 tweets per request and you can make 900 requests per 15-minutes. This means you can theoretically rehydrate 90,000 tweets per 15 minutes, or 360,000 tweets per hour. So it would take approximately 90 minutes to rehydrate all 500,000 of these senators' tweets.

# %%
senators_10_tweets = api.GetStatuses(senators_tweet_ids[:101],map=True)

# %%
api.rate_limit.resources
# Out:
# {'users': {'/users/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550093800}},
#  'statuses': {'/statuses/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550094210},
#   '/statuses/lookup': {'limit': 900, 'remaining': 898, 'reset': 1550094938}}}

# %% [markdown]
# There should be 10 `Status` objects returned by the API.

# %%
len(senators_10_tweets)
# Out:
# 101

# %% [markdown]
# Write a loop to go through the ten tweets and print out information.

# %%
for status in senators_10_tweets.values():
    if type(status) == twitter.models.Status:
        screen_name = status.user.screen_name
        created = pd.to_datetime(status.created_at)
        text = status.full_text
        retweets = status.retweet_count
        formatted_str = '{0} on {1} said {2}, which received {3} retweets.\n'
        print(formatted_str.format(screen_name,created,text,retweets))
# Out:
# DougJones on 2017-12-12 15:16:29+00:00 said RT @AshParso: @GDouglasJones I voted! #DougJones #DougJonesForSenate https://t.co/goIodrE4pR, which received 229 retweets.
#
# DougJones on 2017-12-12 16:51:18+00:00 said Today, let’s get everyone to vote.
#
# Thank you, @JoeBiden https://t.co/2BdAWBZin9, which received 1316 retweets.
#
# DougJones on 2017-12-10 17:24:05+00:00 said "Let us go to the polls to do our own work and remember that our life depends on it, because it does." - Congresswoman Sewell https://t.co/yVnZ8KwjtO, which received 939 retweets.
#
# DougJones on 2017-12-12 14:06:43+00:00 said Today, #RightSideOfHistory
# Go vote! https://t.co/HAWYiHqiez, which received 1052 retweets.
#
# DougJones on 2017-12-12 15:36:12+00:00 said RT @aldotcom: Just in case you were wondering...
#
# #alpolitics #alsen https://t.co/CcYh4mVhtu, which received 552 retweets.
#
#
# DougJones on 2017-12-12 00:29:53+00:00 said Honored to have Sir Charles join the Jones family before our Birmingham GOTV rally &amp; help us share our campaign's message of bringing Alabamians together https://t.co/RrxOktX610, which received 2899 retweets.
#
# DougJones on 2017-12-12 01:21:03+00:00 said “What are the odds of Doug Jones winning? It’s like getting five inches of snow in Birmingham the first week of December!”
# Doug Jones final #GOTV4Doug rally https://t.co/UaWXMiq9e5, which received 343 retweets.
#
# DougJones on 2017-12-12 13:33:31+00:00 said Polls are now open!
# Have you made your plan to vote? Visit https://t.co/1UMDa6L8To or call us at 1-800-682-2793 to help find your polling location or answer any other voter questions!, which received 3971 retweets.
#
# DougJones on 2017-12-12 15:57:26+00:00 said RT @WoodfinForBham: Get out to vote for @GDouglasJones today! Polls are open until 7PM. We can not afford to sit this one out. Let's make h…, which received 1259 retweets.
#
# DougJones on 2017-12-12 15:17:10+00:00 said RT @ShondaScott4: @GDouglasJones I voted for #DougJonesforSenate https://t.co/UukzkYFOxr, which received 309 retweets.
#
# DougJones on 2017-12-10 02:39:19+00:00 said “We have an opportunity on December the 12th for hope and history to rhyme-
#
# We have our history, but we also have our hope. Thank you so much!”
#
# Doug Jones closing with @StP_BrokenBones #GOTV Rally in Birmingham, which received 581 retweets.

# %% [markdown]
# Alternatively, extract the relevant fields, save these as a list of dictionaries, and convert the list of dictionaries to a DataFrame. Note that when an account retweets another account, a second `Status` object is embedded under the "`.retweeted_status`" attribute that contains the parent tweet's information. In these cases, the "`.created_at`" from the Senator's account is when s/he retweeted the status and the "`.created_at`" for the "`.retweeted_status`" is when the parent tweet was first posted.

# %%
statuses_list = []

for status in senators_10_tweets.values():
    if type(status) == twitter.models.Status:
        payload = {}
        payload['screen_name'] = status.user.screen_name
        payload['created'] = pd.to_datetime(status.created_at)
        payload['retweets'] = status.retweet_count
        payload['favorites'] = status.favorite_count
        
        # If an account retweets another account, we should store that information
        if status.retweeted_status == None:
            payload['text'] = status.full_text
            payload['retweeted'] = False
            payload['retweeted_screen_name'] = False
            payload['retweeted_created'] = False
        else:
            payload['text'] = status.retweeted_status.full_text
            payload['retweeted'] = True
            payload['retweeted_screen_name'] = status.retweeted_status.user.screen_name
            payload['retweeted_created'] = status.retweeted_status.created_at
        
        statuses_list.append(payload)
        
df = pd.DataFrame(statuses_list)
df
# Out:
#                       created  favorites  retweeted  \
# 0   2017-12-12 15:16:29+00:00          0       True
# 1   2017-12-12 16:51:18+00:00       5586      False
# 2   2017-12-10 17:24:05+00:00       1840      False
# 3   2017-12-12 14:06:43+00:00       2390      False
# 4   2017-12-12 15:36:12+00:00          0       True
# 5   2017-12-14 18:56:04+00:00       1026      False
# 6   2017-12-12 03:37:09+00:00          0       True
# 7   2017-12-11 21:07:44+00:00       9941      False
# 8   2017-12-10 17:51:23+00:00          0       True
# 9   2017-12-10 05:11:23+00:00       9447      False
# 10  2017-12-10 04:14:15+00:00       4083      False
# 11  2017-12-12 23:59:36+00:00       4334      False
# 12  2017-12-17 14:23:11+00:00       1972      False
# 15                            False                 False       431
# 16                            False                 False      1963
# 17                            False                 False       155
# 18                            False                 False      1152
# 19   Mon Dec 11 16:56:09 +0000 2017              aldotcom      1350
# 20                            False                 False      2460
# 21   Sun Dec 17 15:24:11 +0000 2017             CBSSunday        98
# 22                            False                 False      3267
# 23                            False                 False      1935
# 24                            False                 False       436
# 25                            False                 False      1852
# 26                            False                 False      1056
# 27                            False                 False      1431
# 28                            False                 False        73
# 29                            False                 False       727
# ..                              ...                   ...       ...
# 71                            False                 False    158117
# 72                            False                 False       611
# 73                            False                 False      2432
# 74                            False                 False      2567
# 75                            False                 False      2027
# 76   Mon Dec 11 19:15:17 +0000 2017              UzoAduba       894
# 77                            False                 False       843
# 78                            False                 False      2376
# 79                            False                 False      1862
# 80   Tue Dec 12 19:54:18 +0000 2017          mishacollins      6089
# 81                            False                 False       949
# 82   Fri Dec 15 15:19:24 +0000 2017               CNNSotu       167
# 83                            False                 False       190
# 84   Tue Dec 12 17:22:14 +0000 2017             CalebHx24       543
# 85                            False                 False       851
# 86                            False                 False      1584
# 87                            False                 False       768
# 88                            False                 False      1966
# 89                            False                 False      2572
# 90                            False                 False       511
# 91   Tue Dec 12 18:29:22 +0000 2017         Alyssa_Milano      5822
# 92                            False                 False      2403
# 93   Tue Dec 12 15:33:14 +0000 2017       AnitaFayeSlater       382
# 94   Mon Dec 11 23:30:35 +0000 2017         Alyssa_Milano       918
# 95                            False                 False      2899
# 96                            False                 False       343
# 97                            False                 False      3971
# 98   Tue Dec 12 15:54:52 +0000 2017        randallwoodfin      1259
# 99   Tue Dec 12 15:09:07 +0000 2017          ShondaScott4       309
# 100                           False                 False       581
#
#     screen_name                                               text
# 0     DougJones  @GDouglasJones I voted! #DougJones #DougJonesF...
# 1     DougJones  Today, let’s get everyone to vote.\n\nThank yo...
# 2     DougJones  "Let us go to the polls to do our own work and...
# 3     DougJones  Today, #RightSideOfHistory\nGo vote! https://t...
# 4     DougJones  Just in case you were wondering... \n\n#alpoli...
# 5     DougJones  It was great to join Don Dailey on @APTV to ta...
# 6     DougJones  Alabamians - please get out and vote this Tues...
# 7     DougJones  BREAKING: Charles Barkley, Uzo Aduba of Orange...
# 8     DougJones  With @GDouglasJones, visiting churches in Birm...
# 9     DougJones  Thank you to a great Alabamian, @JasonIsbell, ...
# 10    DougJones  With a capacity crowd inside, some fans even s...
# 11    DougJones  Polls close in ONE HOUR. Make sure to get to y...
# 12    DougJones  "Everyone needs to hit the political reset but...
# 13    DougJones  “I think there’s an opportunity at every turn,...
# 14    DougJones  "When you're on the right side of history you ...
# 15    DougJones  Getting ready to join Savannah Guthrie on the ...
# 16    DougJones  This race could come down to your one vote- if...
# 17    DougJones  @AyeyoKEJO Thanks for the support from one of ...
# 18    DougJones  "We've got to quit playing political football ...
# 19    DougJones  Alabama native Condoleezza Rice says the Senat...
# 20    DougJones  .@MarkRuffalo asks college students in Alabama...
# 21    DougJones  .@BojorquezCBS: Do you think you would have wo...
# 22    DougJones  "When it got to the 14-year-old's story, that ...
# 23    DougJones  Today is incredibly important for the future o...
# 24    DougJones  Doug on Senate #tax bill: "I have real concern...
# 25    DougJones  Our friends across Alabama have already starte...
# 26    DougJones  “We are on the #rightsideofhistory, folks.\n\n...
# 27    DougJones  Don't forget to take an ID with you when votin...
# 28    DougJones  Up next: Doug joins Chris Wallace on Fox News ...
# 29    DougJones  "We have folks across the state rallying aroun...
# ..          ...                                                ...
# 71    DougJones                                Thank you ALABAMA!!
# 72    DougJones  “Each of us in our time is supposed to do what...
# 73    DougJones  "I wouldn't vote for Roy Moore. I think the Re...
# 74    DougJones  Thank you to great Alabamians Mike Cooley and ...
# 75    DougJones  “We have come so far and the people of Alabama...
# 76    DougJones  I’m down in Alabama today talking to the incre...
# 77    DougJones  Have any questions? Call us at 1-800-682-2793 ...
# 78    DougJones  “You know if somebody told you guys, put this ...
# 79    DougJones  .@mishacollins has a message for the young vot...
# 80    DougJones  This video proves that @JensenAckles physicall...
# 81    DougJones  Doug &amp; Louise join Senator Booker, Congres...
# 82    DougJones  This Sunday Senator-elect @GDouglasJones joins...
# 83    DougJones  "It doesn't matter what the issue is. There's ...
# 84    DougJones  @GDouglasJones First time voter! #DougJonesFor...
# 85    DougJones  Polls close in 30 minutes. Make sure to get to...
# 86    DougJones  “Today has always been a special day, today is...
# 87    DougJones  Thank you, @BellamyYoung for your kind words a...
# 88    DougJones  “History says don't hope on this side of the g...
# 89    DougJones  Thank you @kerrywashington for your support an...
# 90    DougJones  “This is the most significant election our sta...
# 91    DougJones  Driving people to the polls! #GOTV4Doug https:...
# 92    DougJones  It’s Election Day! Polls open at 7am. Confirm ...
# 93    DougJones  @GDouglasJones I voted! 💙💯:) #RightSideOfHisto...
# 94    DougJones  With @UzoAduba at #UAB! #GoBlazers #GOTV4Doug ...
# 95    DougJones  Honored to have Sir Charles join the Jones fam...
# 96    DougJones  “What are the odds of Doug Jones winning? It’s...
# 97    DougJones  Polls are now open! \nHave you made your plan ...
# 98    DougJones  Get out to vote for @GDouglasJones today! Poll...
# 99    DougJones  @GDouglasJones I voted for #DougJonesforSenate...
# 100   DougJones  “We have an opportunity on December the 12th f...
#
# [101 rows x 8 columns]

# %% [markdown]
# ## Pulling a user's timeline
#
# In the previous class, we wrote a screen-scraper to retrieve the tweet timelines of government officials. This broke Twitter's Terms of Service but is probably defensible under emerging legal precedents applying public forum doctrine and government speech to these accounts.
#
# In general, if you want to retrieve the tweets from a user's timeline, we can use Twitter's API to get the 3,200 most recent tweets from the [get statuses/user_timeline](https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline.html) API endpoint. This will include retweets of other statuses. We can retrieve up to 200 tweets per request and can make 900 requests per 15-minute window, so we can get 18,000 tweets per window or 72,000 tweets per hour. This means we could theoretically get up to 22 users' most recent 3,200 tweets per hour.
#
# Alexandria Ocasio-Cortez has written 6,975 tweets on her personal account, "[AOC](https://twitter.com/aoc)". She also has an official account "[RepAOC](https://twitter.com/repaoc)", but this only has 14 tweets. Let's get her 3,200 most-recent tweets from the API. Disappointingly, `python-twitter` does not handle the "pagination" for us so we can only ask for 200 tweets at a time and have to update when to ask for the next tweets.

# %%
aoc_tweets = api.GetUserTimeline(screen_name='aoc',count=200,include_rts=True)
print("{0:,} tweets were returned.".format(len(aoc_tweets)))
# Out:
# 200 tweets were returned.

# %% [markdown]
# The first tweet returned is the most recent tweet.

# %%
aoc_tweets[0].created_at
# Out:
# 'Wed Feb 13 20:29:14 +0000 2019'

# %% [markdown]
# The last tweet returned (the 200th).

# %%
aoc_tweets[-1].created_at
# Out:
# 'Wed Jan 30 19:19:00 +0000 2019'

# %% [markdown]
# We really care about the final tweet's ID so we can make an API query that asks for the next 200 statuses before the last tweet returned.

# %%
aoc_tweets[-1].id
# Out:
# 1089949096197218305

# %% [markdown]
# Now we make the next query.

# %%
aoc_tweets2 = api.GetUserTimeline(screen_name='aoc',count=200,include_rts=True,max_id=aoc_tweets[-1].id)

# %% [markdown]
# Check the first tweet in here.

# %%
aoc_tweets2[0].id
# Out:
# 1090690861938163715

# %% [markdown]
# Now we'll write a loop to get all 3,200 tweets.

# %%
# Start with the list of the 200 most-recent tweets
timeline_tweets = api.GetUserTimeline(screen_name='aoc',count=200,include_rts=True)

# Initialize a counter so we don't go overboard with our requests
request_counter = 1

# While our request counter hasn't gone past 16
while request_counter < 17:
    # Get the most oldest tweet id
    final_status_id = timeline_tweets[-1].id
    
    # Pass this tweet ID into the max_id parameter, minus 1 so we don't duplicate it
    timeline_tweets += api.GetUserTimeline(screen_name='aoc',count=200,include_rts=True,max_id=final_status_id-1)
    
    # Increment our request_counter
    request_counter += 1

# %% [markdown]
# We can also abstract this into a function we could use for anyone's timeline.

# %%
def get_all_user_timeline(screen_name,count=200,include_rts=True):
    
    # Start with the list of the 200 most-recent tweets
    timeline_tweets = api.GetUserTimeline(screen_name=screen_name,count=count,include_rts=include_rts)

    # Initialize a counter so we don't go overboard with our requests
    request_counter = 1

    # While our request counter hasn't gone past 16
    while request_counter < 17:
        # Get the most oldest tweet id
        final_status_id = timeline_tweets[-1].id

        # Pass this tweet ID into the max_id parameter, minus 1 so we don't duplicate it
        timeline_tweets += api.GetUserTimeline(screen_name='aoc',count=200,include_rts=True,max_id=final_status_id-1)

        # Increment our request_counter
        request_counter += 1
        
    return timeline_tweets

# %% [markdown]
# Somehow a few more tweets snuck in there.

# %%
len(timeline_tweets)
# Out:
# 3219

# %% [markdown]
# I've added a lot more sugar into our loop to grab information about replies, user mentions, and hashtags.

# %%
statuses_list = []

for status in timeline_tweets:
    if type(status) == twitter.models.Status:
        payload = {}
        payload['screen_name'] = status.user.screen_name
        payload['created'] = pd.to_datetime(status.created_at)
        payload['retweets'] = status.retweet_count
        payload['favorites'] = status.favorite_count
        payload['id'] = status.id
        payload['reply_screen_name'] = status.in_reply_to_screen_name
        payload['reply_id'] = status.in_reply_to_status_id
        payload['source'] = BeautifulSoup(status.source).text
        
        if len(status.user_mentions) > 0:
            payload['user_mentions'] = '; '.join([m.screen_name for m in status.user_mentions])
        else:
            payload['user_mentions'] = None
            
        if len(status.hashtags) > 0:
            payload['hashtags'] = '; '.join([h.text for h in status.hashtags])
        else:
            payload['hashtags'] = None
        
        # If an account retweets another account, we should store that information
        if status.retweeted_status == None:
            payload['text'] = status.full_text
            payload['is_retweet'] = False
            payload['retweeted_screen_name'] = False
            payload['retweeted_created'] = False
        else:
            payload['text'] = status.retweeted_status.full_text
            payload['is_retweet'] = True
            payload['retweeted_screen_name'] = status.retweeted_status.user.screen_name
            payload['retweeted_created'] = status.retweeted_status.created_at
            payload['retweeted_source'] = BeautifulSoup(status.retweeted_status.source).text
            if len(status.retweeted_status.hashtags) > 0:
                payload['hashtags'] = '; '.join([h.text for h in status.retweeted_status.hashtags])
            else:
                payload['hashtags'] = None
        
        statuses_list.append(payload)
        
df = pd.DataFrame(statuses_list)
df.head()
# Out:
#                     created  favorites hashtags                   id  \
# 0 2019-02-13 20:29:14+00:00      12535     None  1095781966522318849
# 1 2019-02-13 19:19:20+00:00      27567     None  1095764378954141696
# 2 2019-02-13 19:16:14+00:00      42958     None  1095763596062150656
# 3 2019-02-13 03:43:39+00:00      55451     None  1095528904805228545
# 4 2019-02-13 01:08:23+00:00      77556     None  1095489830656589824
#
#    is_retweet      reply_id reply_screen_name retweeted_created  \
# 0       False           NaN              None             False
# 1       False  1.095764e+18               AOC             False
# 2       False           NaN              None             False
# 3       False           NaN              None             False
# 4       False           NaN              None             False
#
#   retweeted_screen_name retweeted_source  retweets screen_name  \
# 0                 False              NaN      1673         AOC
# 1                 False              NaN      6614         AOC
# 2                 False              NaN     17088         AOC
# 3                 False              NaN     10824         AOC
# 4                 False              NaN     15596         AOC
#
#                source                                               text  \
# 0  Twitter for iPhone     Bringing the BX to DC! https://t.co/aJRZsXDVfV
# 1  Twitter for iPhone  Apparently this is a normal practice, and peop...
# 2  Twitter for iPhone  Shock doesn’t begin to cover it.\n\nToday I le...
# 3  Twitter for iPhone  Reminder that their plan = no plan.\n\nWhy? Be...
# 4  Twitter for iPhone  Don’t mess with our future.\n\nWhen it comes t...
#
#   user_mentions
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %% [markdown]
# Convert the "created" column into a proper `datetime` object and extract the dates as another column.

# %%
df['timestamp'] = pd.to_datetime(df['created'])
df['date'] = df['timestamp'].apply(lambda x:x.date())
df['weekday'] = df['timestamp'].apply(lambda x:x.weekday)
df['hour'] = df['timestamp'].apply(lambda x:x.hour)

# %% [markdown]
# Make a plot of the number of tweets by date.

# %%
# Group by date and aggregate by number of tweets on that date
_s = df.groupby('date').agg({'id':len,'is_retweet':'sum','reply_id':lambda x:sum(x.notnull())})

# Reindex the data to be continuous over the range, fill in missing dates as 0s
_min_date, _max_date = _s.index.min(), _s.index.max()
_s = _s.reindex(pd.date_range(_min_date,_max_date),fill_value=0)
_s.columns = ['Tweets','Retweets','Replies']
_s_frac = _s[['Retweets','Replies']].div(_s['Tweets'],axis=0).fillna(0)

# Make the plot
f,axs = plt.subplots(2,1,figsize=(8,6))
_s['Tweets'].rolling(3).mean().plot(ax=axs[0])
_s_frac.rolling(3).mean().plot(ax=axs[1],legend=False)

axs[0].legend(loc='center left',bbox_to_anchor=(1,.5))
axs[1].legend(loc='center left',bbox_to_anchor=(1,.5))
axs[0].set_ylabel('Count')
axs[1].set_ylabel('Fraction of tweets')

# Annotate the plot with lines corresponding to major events
for ax in axs:
    ax.axvline(pd.Timestamp('2018-06-26'),lw=3,c='k',alpha=.25) # Primary win
    ax.axvline(pd.Timestamp('2018-11-06'),lw=3,c='k',alpha=.25) # Election day
    ax.axvline(pd.Timestamp('2019-01-03'),lw=3,c='k',alpha=.25) # Swearing in
    
axs[0].annotate(xy=(pd.Timestamp('2018-06-26')+pd.Timedelta(3,'d'),47.5),s='Primary\nwin',va='center')
axs[0].annotate(xy=(pd.Timestamp('2018-11-06')+pd.Timedelta(3,'d'),47.5),s='Election',va='center')
axs[0].annotate(xy=(pd.Timestamp('2019-01-03')+pd.Timedelta(3,'d'),47.5),s='Sworn\nin',va='center')

f.tight_layout()
f.savefig('aoc_activity.png',dpi=300,bbox_inches='tight')

# %%
# Group by the date and aggregate by the sum of retweets and favorites for all tweets on that date
_s = df.groupby('date').agg({'retweets':'sum','favorites':'sum'})

# Reindex the data to be continuous over the range, fill in missing dates as 0s
_min_date, _max_date = _s.index.min(), _s.index.max()
_s = _s.reindex(pd.date_range(_min_date,_max_date),fill_value=0)

# Make the plot
f,ax = plt.subplots(1,1,figsize=(8,4))
ax = _s.rolling(3).mean().plot(legend=False,lw=2,ax=ax)
ax.set_ylim((0,1200000))
ax.legend(loc='center left',bbox_to_anchor=(1,.5))
ax.set_title('Daily engagement with @aoc tweets')

# Annotate the plot with lines corresponding to major events
ax.axvline(pd.Timestamp('2018-06-26'),lw=3,c='k',alpha=.25) # Primary win
ax.axvline(pd.Timestamp('2018-11-06'),lw=3,c='k',alpha=.25) # Election day
ax.axvline(pd.Timestamp('2019-01-03'),lw=3,c='k',alpha=.25) # Swearing in

ax.annotate(xy=(pd.Timestamp('2018-06-26')+pd.Timedelta(3,'d'),1100000),s='Primary\nwin',va='center')
ax.annotate(xy=(pd.Timestamp('2018-11-06')+pd.Timedelta(3,'d'),1100000),s='Election',va='center')
ax.annotate(xy=(pd.Timestamp('2019-01-03')+pd.Timedelta(3,'d'),1100000),s='Sworn\nin',va='center')

f.tight_layout()
f.savefig('aoc_engagement.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# We can also do a bit of sentiment analysis. You'll likely need to [install the NLTK data](https://www.nltk.org/data.html) for this to work. We are going to use the [VADER sentiment analysis tool](https://github.com/cjhutto/vaderSentiment) that was specifically trained for social media text: [see paper here](http://comp.social.gatech.edu/papers/icwsm14.vader.hutto.pdf).

# %%
# Get sentiment scores for each tweet's text
df['sentiment'] = df['text'].apply(lambda x:sia.polarity_scores(x)['compound'])

# %% [markdown]
# Plot out the daily sentiment of tweets with major events annotated.

# %%
# Group by the date and aggregate by the average sentiment for all tweets on that date
_s = df.groupby('date').agg({'sentiment':'mean'})

# Reindex the data to be continuous over the range, fill in missing dates as 0s
_min_date, _max_date = _s.index.min(), _s.index.max()
_s = _s.reindex(pd.date_range(_min_date,_max_date),fill_value=0)

# Make the plot with a 7-day rolling average
f,ax = plt.subplots(1,1,figsize=(8,4))
ax = _s.rolling(3).mean().plot(legend=False,ax=ax)
ax.set_ylim((-.3,.6))
ax.axhline(0,ls='--',c='k',lw=1)
ax.set_title('Sentiment of @aoc tweets')
ax.set_ylabel('Compound VADER score')

# Annotate the plot with lines corresponding to major events
ax.axvline(pd.Timestamp('2018-06-26'),lw=3,c='k',alpha=.25) # Primary win
ax.axvline(pd.Timestamp('2018-11-06'),lw=3,c='k',alpha=.25) # Election day
ax.axvline(pd.Timestamp('2019-01-03'),lw=3,c='k',alpha=.25) # Swearing in

ax.annotate(xy=(pd.Timestamp('2018-06-26')+pd.Timedelta(3,'d'),.525),s='Primary\nwin',va='center')
ax.annotate(xy=(pd.Timestamp('2018-11-06')+pd.Timedelta(3,'d'),.525),s='Election',va='center')
ax.annotate(xy=(pd.Timestamp('2019-01-03')+pd.Timedelta(3,'d'),.525),s='Sworn\nin',va='center')

f.tight_layout()
f.savefig('aoc_sentiment.png',dpi=300,bbox_inches='tight')

# %% [markdown]
# Compute the engagement for @AOC tweets, ignoring retweets and replies, and normalizing for total tweet activity on that day.

# %%
c1 = ~df['is_retweet']
c2 = df['reply_id'].isnull()

pure_tweets_df = df[c1 & c2]
print("There are {0:,} tweets that are not retweets or replies.".format(len(pure_tweets_df)))

_s = pure_tweets_df.groupby('date').agg({'retweets':'sum','favorites':'sum','id':len})
_s = _s[['retweets','favorites']].div(_s['id'],axis=0)
_s.columns = ['Retweets','Favorites']

# Reindex the data to be continuous over the range, fill in missing dates as 0s
_min_date, _max_date = _s.index.min(), _s.index.max()
_s = _s.reindex(pd.date_range(_min_date,_max_date),fill_value=0)

# Make the plot
f,ax = plt.subplots(1,1,figsize=(8,4))
ax = _s.rolling(3).mean().plot(legend=False,lw=2,ax=ax)
# ax.set_yscale('symlog')
# ax.set_ylim((1e1,1e6))

ax.legend(loc='center left',bbox_to_anchor=(1,.5))
ax.set_title('Daily engagement with @aoc tweets')
ax.set_ylabel('Engagement per tweet')

# Annotate the plot with lines corresponding to major events
ax.axvline(pd.Timestamp('2018-06-26'),lw=3,c='k',alpha=.25) # Primary win
ax.axvline(pd.Timestamp('2018-11-06'),lw=3,c='k',alpha=.25) # Election day
ax.axvline(pd.Timestamp('2019-01-03'),lw=3,c='k',alpha=.25) # Swearing in

ax.annotate(xy=(pd.Timestamp('2018-06-26')+pd.Timedelta(3,'d'),130000),s='Primary\nwin',va='center')
ax.annotate(xy=(pd.Timestamp('2018-11-06')+pd.Timedelta(3,'d'),130000),s='Election',va='center')
ax.annotate(xy=(pd.Timestamp('2019-01-03')+pd.Timedelta(3,'d'),130000),s='Sworn\nin',va='center')

f.tight_layout()
f.savefig('aoc_engagement_no_rt_reply.png',dpi=300,bbox_inches='tight')
# Out:
# There are 1,346 tweets that are not retweets or replies.

# %% [markdown]
# Plot favorites per retweet.

# %%
f,ax = plt.subplots(1,1,figsize=(8,4))

(_s['Retweets']/_s['Favorites']).fillna(0).rolling(3).mean().plot(ax=ax)

ax.set_ylim((0,.5))

# Annotate the plot with lines corresponding to major events
ax.axvline(pd.Timestamp('2018-06-26'),lw=3,c='k',alpha=.25) # Primary win
ax.axvline(pd.Timestamp('2018-11-06'),lw=3,c='k',alpha=.25) # Election day
ax.axvline(pd.Timestamp('2019-01-03'),lw=3,c='k',alpha=.25) # Swearing in

ax.annotate(xy=(pd.Timestamp('2018-06-26')+pd.Timedelta(3,'d'),.45),s='Primary\nwin',va='center')
ax.annotate(xy=(pd.Timestamp('2018-11-06')+pd.Timedelta(3,'d'),.45),s='Election',va='center')
ax.annotate(xy=(pd.Timestamp('2019-01-03')+pd.Timedelta(3,'d'),.45),s='Sworn\nin',va='center')
# Out:
# Text(2019-01-06 00:00:00, 0.45, 'Sworn\nin')

# %% [markdown]
# What are the top tweets by retweets per favorite? The're primarily from before her primary win.

# %%
df['rt_fav_ratio'] = (df['retweets']/df['favorites']).replace({np.inf:np.nan})
top_retweets = df['rt_fav_ratio'].dropna().sort_values(ascending=False).head(10)
df.loc[top_retweets.index,['created','text','retweets','favorites']]
# Out:
#                        created  \
# 2796 2018-06-12 02:18:10+00:00
# 3156 2018-05-26 19:58:24+00:00
# 3176 2018-05-25 20:43:50+00:00
# 2543 2018-06-20 19:24:23+00:00
# 2565 2018-06-19 23:55:13+00:00
# 2671 2018-06-16 19:04:03+00:00
# 2548 2018-06-20 17:40:00+00:00
# 2342 2018-06-26 11:45:17+00:00
# 2514 2018-06-21 17:04:20+00:00
# 2962 2018-06-05 16:48:21+00:00
#
#                                                    text  retweets  favorites
# 2796  @BenjSilv @nycDSA It’s a remote team! People a...         5          3
# 3156  @itismikemcd People take this for granted, but...        82         78
# 3176  ICE has LOST 1,400 children that they had sepa...      2845       3172
# 2543  Labor unions @UFCW, @GoIUPAT, &amp; @RWDSU rep...       214        259
# 2565  We're looking for bilingual (SP) volunteers re...       105        129
# 2671  We're looking for volunteers registered to vot...       451        617
# 2548  One horrific part about #FamilySeparation &amp...       585        880
# 2342  Don't know where to go or how to help today?\n...       326        505
# 2514  .@repjoecrowley’s #2 all-time career donor, Bl...       999       1555
# 2962  Surprise, surprise: last-minute pollsite chang...       633       1015

# %% [markdown]
# Is there an intereseting relationship between seniment and retweet/favorite ratio? We can specify a simple univariate LOESS regression for the relationship between sentiment and the retweet-per-favorite ratio. It appears that extremely negative and positive tweets have higher ratios than neutral tweets.

# %%
g = sb.lmplot(x='sentiment',y='rt_fav_ratio',data=df,lowess=True,aspect=2,
              line_kws={'color':'red','linewidth':10,'alpha':.5})
ax = g.axes[0,0]
ax.set_ylim((0,1))
# Out:
# (0, 1)

# %% [markdown]
# ## Pulling a user's friends
#
# In the parlance of the Twitter API, the people who follow an account are "followers" and the people followed by an account are "friends". There's unfortuantely no timestamp meta-data about when friend and follower relationships were created. The API limits on this are much more stringent than other API calls: only 200 accounts per request and only 15 requests per 15-minute window: basically 200 accounts per minute or 3,000 accounts before you hit the rate limit. AOC has 1,417 friends, so it takes 8 API requests to get them all, leaving me with 7 requests in this 15-minute window.

# %%
aoc_friends = api.GetFriends(screen_name='aoc',count=200,skip_status=True)
print("There are {0:,} friends.".format(len(aoc_friends)))
# Out:
# There are 1,422 friends.

# %% [markdown]
# We can check my API rate limit status too.

# %%
api.rate_limit.resources
# Out:
# {'users': {'/users/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550093800}},
#  'statuses': {'/statuses/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550094210},
#   '/statuses/lookup': {'limit': 900, 'remaining': 898, 'reset': 1550094938},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 881,
#    'reset': 1550095411}},
#  'friends': {'/friends/list': {'limit': 15,
#    'remaining': 7,
#    'reset': 1550096241}}}

# %% [markdown]
# More specifically:

# %%
api.rate_limit.resources['friends']['/friends/list']['remaining']
# Out:
# 7

# %% [markdown]
# This resets at:

# %%
datetime.fromtimestamp(api.rate_limit.resources['friends']['/friends/list']['reset']).strftime('%H:%M:%S')
# Out:
# '15:17:21'

# %% [markdown]
# I think "friends" convey much more valuable information about an account than followers, primarily because an account doesn't choose who follows them. However, if you wanted to get the followers of an account, we use the `GetFollowers` method. I'm only going to grab 200 so I don't burn more API calls.

# %%
aoc_followers = api.GetFollowers(screen_name='aoc',skip_status=True,total_count=200)

# %%
api.rate_limit.resources
# Out:
# {'users': {'/users/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550093800}},
#  'statuses': {'/statuses/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550094210},
#   '/statuses/lookup': {'limit': 900, 'remaining': 898, 'reset': 1550094938},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 881,
#    'reset': 1550095411}},
#  'friends': {'/friends/list': {'limit': 15,
#    'remaining': 7,
#    'reset': 1550096241}},
#  'followers': {'/followers/list': {'limit': 15,
#    'remaining': 14,
#    'reset': 1550096362}}}

# %% [markdown]
# We can access these user objects to pull out interesting meta-data.

# %%
aoc_friends[0].name
# Out:
# 'AFA-CWA'

# %%
aoc_friends[0].description
# Out:
# 'The Association of Flight Attendants-CWA, AFL-CIO is the Flight Attendant union representing 50,000 Flight Attendants at 20 different airlines.'

# %%
aoc_friends[0].screen_name
# Out:
# 'afa_cwa'

# %%
aoc_friends[0].created_at
# Out:
# 'Fri Jul 31 18:47:29 +0000 2009'

# %%
aoc_friends[0].statuses_count
# Out:
# 5107

# %%
aoc_friends[0].followers_count
# Out:
# 8407

# %%
aoc_friends[0].friends_count
# Out:
# 1364

# %%
aoc_friends[0].verified
# Out:
# True

# %%
aoc_friends[0].id
# Out:
# 22709207

# %% [markdown]
# Loop through all the friends of @aoc and turn it into a DataFrame.

# %%
aoc_friend_payloads = []

for friend in aoc_friends:
    p = {}
    p['name'] = friend.name
    p['description'] = friend.description
    p['screen_name'] = friend.screen_name
    p['created_at'] = friend.created_at
    p['statuses_count'] = friend.statuses_count
    p['followers_count'] = friend.followers_count
    p['friends_count'] = friend.friends_count
    p['verified'] = friend.verified
    p['id'] = friend.id
    aoc_friend_payloads.append(p)
    
aoc_friend_df = pd.DataFrame(aoc_friend_payloads)
aoc_friend_df['created_at'] = pd.to_datetime(aoc_friend_df['created_at'])
aoc_friend_df['created_at'] = aoc_friend_df['created_at'].dt.tz_convert(None)
aoc_friend_df['account_age'] = aoc_friend_df['created_at'].apply(lambda x:(datetime.now() - x)/pd.Timedelta(1,'d'))
aoc_friend_df.head()
# Out:
#            created_at                                        description  \
# 0 2009-07-31 18:47:29  The Association of Flight Attendants-CWA, AFL-...
# 1 2010-02-16 21:44:24  Contributor, https://t.co/iNAAZlt7nZ. Columnis...
# 2 2009-03-04 00:52:57  Policy lead for the #GreenNewDeal @newconsensu...
# 3 2019-01-03 15:51:05  Cultivating the next generation of leaders and...
# 4 2016-12-08 17:00:41  Proudly serving MD's 8th District. Member of: ...
#
#    followers_count  friends_count                   id                name  \
# 0             8407           1364             61843868             AFA-CWA
# 1            79519            708            114870265       Peter Beinart
# 2             4655            320             22709207  Rhiana Gunn-Wright
# 3             2515            214  1080854064567668736     Movement School
# 4            48737           4586   806906355214852096   Rep. Jamie Raskin
#
#     screen_name  statuses_count  verified  account_age
# 0       afa_cwa            5107      True  3483.845773
# 1  PeterBeinart           28249      True  3283.722914
# 2        rgunns            1361     False  3633.591977
# 3    mvmtschool             107     False    40.968273
# 4     RepRaskin            5415      True   796.919940

# %% [markdown]
# In this sample of Twitter accounts, are there any interesting trends in verified accounts?

# %%
f,axs = plt.subplots(1,4,figsize=(16,4),sharey=True)

sb.barplot(x='verified',y='followers_count',data=aoc_friend_df,ax=axs[0],estimator=np.median,errwidth=5)
sb.barplot(x='verified',y='friends_count',data=aoc_friend_df,ax=axs[1],estimator=np.median,errwidth=5)
sb.barplot(x='verified',y='statuses_count',data=aoc_friend_df,ax=axs[2],estimator=np.median,errwidth=5)
sb.barplot(x='verified',y='account_age',data=aoc_friend_df,ax=axs[3],estimator=np.median,errwidth=5)

axs[0].set_title('Followers')
axs[1].set_title('Friends')
axs[2].set_title('Statuses')
axs[3].set_title('Account age (days)')

# As we'll see below, having more than 5,000 friends could complicate our sampling
axs[0].axhline(5000,ls='--',c='k')
axs[1].axhline(5000,ls='--',c='k')
axs[2].axhline(3200,ls='--',c='k')

for ax in axs:
    ax.set_ylim((1e2,1e5))
    ax.set_yscale('symlog')
    ax.set_ylabel(None)

f.tight_layout()
# Out:
# /Users/briankeegan/anaconda/lib/python3.6/site-packages/scipy/stats/stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Are these differences statistically-significant? Let's run some [t-tests](https://en.wikipedia.org/wiki/T-test).

# %%
from scipy import stats

for var in ['followers_count','friends_count','statuses_count','account_age']:
    vals1 = aoc_friend_df.loc[aoc_friend_df['verified'] == True,var]
    vals2 = aoc_friend_df.loc[aoc_friend_df['verified'] == False,var]
    test,pvalue = stats.ttest_ind(vals1,vals2)
    str_fmt = "The differences in {0}: t = {1:.2f} \t p={2:.3f}"
    print(str_fmt.format(var,test,pvalue))
# Out:
# The differences in followers_count: t = 4.97 	 p=0.000
# The differences in friends_count: t = 2.04 	 p=0.041
# The differences in statuses_count: t = 8.87 	 p=0.000
# The differences in account_age: t = 10.65 	 p=0.000

# %% [markdown]
# Or use the non-parametric [Mann-Whitney U-test](https://en.wikipedia.org/wiki/Mann%E2%80%93Whitney_U_test) since our data is so skewed.

# %%
for var in ['followers_count','friends_count','statuses_count','account_age']:
    vals1 = aoc_friend_df.loc[aoc_friend_df['verified'] == True,var]
    vals2 = aoc_friend_df.loc[aoc_friend_df['verified'] == False,var]
    test,pvalue = stats.mannwhitneyu(vals1,vals2)
    str_fmt = "The differences in {0}: U = {1:,.0f} \t p = {2:,.3f}"
    print(str_fmt.format(var,test,pvalue))
# Out:
# The differences in followers_count: U = 54,820 	 p = 0.000
# The differences in friends_count: U = 183,080 	 p = 0.000
# The differences in statuses_count: U = 139,513 	 p = 0.000
# The differences in account_age: U = 171,629 	 p = 0.000

# %% [markdown]
# Unsurprisingly, verified accounts have more followers and are older than non-verified accounts. But they also appear to be more active and have more friends.

# %% [markdown]
# ### Ego-network
# We can make a 1.5-step ego-network of the accounts @aoc follows and the accounts each of them follow. Using the `GetFriends` is too "expensive" because it cost us 8 API calls to get a single account's followers since it only returns 200 accounts at a time. Twitter also exposes a [get friends/ids](https://developer.twitter.com/en/docs/accounts-and-users/follow-search-get-users/api-reference/get-friends-ids) end-point that will return up to 5,000 user IDs per request. The number of requests remains 15 requests per 15-minute window, but we can now get the friend networks for 15 accounts per 15 minutes rather than maybe only 1 or 2. The challenge with this is that we will need to "rehydrate" these user IDs at some point.
#
# Here, we'll use the "total_count" parameter to limit it to 5,000 accounts in case one of these accounts follows thousands of accounts.
#
# Store the data in a dictionary keyed by account name and with the list of user IDs integers as values. Initialize with @aoc.

# %%
aoc_friends_d = {'aoc':api.GetFriendIDs(screen_name='aoc',total_count=5000,count=5000)}

# %%
api.rate_limit.resources
# Out:
# {'users': {'/users/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550093800}},
#  'statuses': {'/statuses/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550094210},
#   '/statuses/lookup': {'limit': 900, 'remaining': 898, 'reset': 1550094938},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 881,
#    'reset': 1550095411}},
#  'friends': {'/friends/list': {'limit': 15,
#    'remaining': 7,
#    'reset': 1550096241},
#   '/friends/ids': {'limit': 15, 'remaining': 14, 'reset': 1550096667}},
#  'followers': {'/followers/list': {'limit': 15,
#    'remaining': 14,
#    'reset': 1550096362}}}

# %%
aoc_friends_d['aoc']
# Out:
# [61843868,
#  114870265,
#  22709207,
#  1080854064567668736,
#  806906355214852096,
#  1079802482640019456,
#  713217283246530560,
#  78706973,
#  2468096389,
#  3321135820,
#  28796289,
#  47646735,
#  516880804,
#  305307067,
#  24506246,
#  175183717,
#  240812994,
#  95270375,
#  5770442,
#  217708411,
#  829760984,
#  180681251,
#  103018203,
#  124628664,
#  953642468028841984,
#  140519774,
#  1079769536730140672,
#  120342217,
#  297067961,
#  27789237,
#  586291040,
#  7141302,
#  16341344,
#  19034656,
#  25694156,
#  80612021,
#  216921189,
#  1395871423,
#  111122177,
#  1879944877,
#  2735293897,
#  826981458946424833,
#  40788497,
#  3246501357,
#  18567903,
#  962585492,
#  61242633,
#  19374372,
#  307434638,
#  845303572388593664,
#  821940204814602240,
#  899739707843727360,
#  831972659609104384,
#  121787593,
#  741000470,
#  818040343,
#  892491627088011264,
#  24560143,
#  855556862,
#  45879022,
#  3598442532,
#  473619428,
#  22447078,
#  93907882,
#  1944680329,
#  852179048419794946,
#  809250675792244736,
#  64326023,
#  23232204,
#  27711685,
#  30488144,
#  335972576,
#  77347110,
#  254189414,
#  825717580337905665,
#  751902676011479040,
#  1040931031,
#  3141672447,
#  828041707128311815,
#  17929529,
#  4173811888,
#  355591226,
#  130496027,
#  949934436,
#  15283286,
#  22530626,
#  874113037892034561,
#  37074061,
#  59806641,
#  838239860263636992,
#  6576492,
#  76229389,
#  12133382,
#  3016964678,
#  488620840,
#  800707492346925056,
#  836449242604531712,
#  11757522,
#  15729844,
#  1247612029,
#  393588826,
#  102802196,
#  468752446,
#  10069612,
#  14695985,
#  948527498,
#  862430010,
#  29447358,
#  112471133,
#  148529707,
#  743155123258531840,
#  40364287,
#  18208354,
#  357606935,
#  21827037,
#  145348411,
#  136150088,
#  55338739,
#  72198806,
#  19834403,
#  747836013310021632,
#  137626624,
#  2171052229,
#  24130824,
#  148397910,
#  23708602,
#  1337524615,
#  2216041938,
#  111416652,
#  357092583,
#  471454646,
#  160720376,
#  18363255,
#  2504452635,
#  19259102,
#  727034425,
#  12388512,
#  42971403,
#  81168306,
#  29134273,
#  17266725,
#  376243560,
#  2750877815,
#  19119809,
#  17973162,
#  19404112,
#  811050248357511168,
#  31129627,
#  36510146,
#  17872898,
#  620096179,
#  3195871562,
#  3125720528,
#  34487135,
#  144533152,
#  26548315,
#  313644703,
#  919470745,
#  89887215,
#  15275864,
#  71411021,
#  16411233,
#  97732452,
#  519072324,
#  2983369510,
#  79923701,
#  36707799,
#  939091,
#  164007407,
#  33563161,
#  164369297,
#  1252002462,
#  249469549,
#  351065668,
#  26043268,
#  249217178,
#  1483355989,
#  ...]

# %% [markdown]
# Check there's still something like 1,400 for "aoc".

# %%
len(aoc_friends_d['aoc'])
# Out:
# 1422

# %% [markdown]
# How many accounts have more than 5000 friends? So about 10% of our network will be incomplete if we limit to only a single "page" of 5,000 user IDs per follower.

# %%
gt5000_aoc_friend_df = aoc_friend_df[aoc_friend_df['friends_count'] > 5000]
len(gt5000_aoc_friend_df)
# Out:
# 147

# %% [markdown]
# Who are some of these high-friend accounts? Even at 5,000 friends per request, it will still cost you 123 API requests (and thus 123 minutes) to get Barack Obama's 615,000 friends.

# %%
subset_cols = ['name','screen_name','friends_count','followers_count','description']
gt5000_aoc_friend_df.sort_values('friends_count',ascending=False).head(10)[subset_cols]
# Out:
#                      name     screen_name  friends_count  followers_count  \
# 1295           Taye Diggs       TayeDiggs         661644           639662
# 1225         Barack Obama     BarackObama         615828        104589725
# 978       Soledad O'Brien   soledadobrien         453851           933678
# 410      Twitter Verified        verified         315125          2609343
# 1169  Millennial Politics  MillenPolitics          92956           111300
# 109           Cory Booker      CoryBooker          92840          4169740
# 1168      Nathan H. Rubin    NathanHRubin          74929            79562
# 1248                  NPR             NPR          71247          7674341
# 726         Elianne Ramos   ergeekgoddess          69115            54210
# 915                   PBS             PBS          51181          2253150
#
#                                             description
# 1295  I'm serious chocolate and don't get it twisted...
# 1225                  Dad, husband, President, citizen.
# 978                                    Thank you, next.
# 410   Twitter is working on a new authentication and...
# 1169  Shining a spotlight on progressive candidates,...
# 109   U.S. senator from New Jersey and Democratic ca...
# 1168  Founder, @MillenPolitics. Young Leaders Board,...
# 1248  News. Arts & Life. Music. Everything and more ...
# 726   Hopelessly Undomestic | Speaker | Public Affai...
# 915   PBS invites you to discover new ideas and expl...

# %% [markdown]
# This loop will go through the list of `aoc_friends` (a list of `User` objects) and then get the 5,000 friends' user IDs for each of them. With these rate limits of 15 requests per 15 min, it will take 1417 minutes (23.6 hours) to get our sample of data for AOC's 1,417 friends. You can now start to see the appeal of parallelizing requests!
#
# You probably don't want to run this loop.

# %% [raw]
# for friend in aoc_friends:
#     if friend not in aoc_friends_d.keys():
#         friend_id = friend.id
#         try:
#             aoc_friends_d[friend_id] = api.GetFriendIDs(user_id=friend_id,count=5000,total_count=5000)
#         except twitter.error.TwitterError:
#             reset_time = api.rate_limit.resources['friends']['/friends/ids']['reset']
#             sleep_time = (datetime.fromtimestamp(reset_time) - datetime.now())/timedelta(seconds=1) + 1
#             time.sleep(sleep_time)
#             aoc_friends_d[friend_id] = api.GetFriendIDs(user_id=friend_id,count=5000,total_count=5000)
#         with open('aoc_friend_ids.json','w') as f:
#             json.dump(aoc_friends_d,f)

# %% [markdown]
# Instead, I've done this scraping for you and saved the results in a JSON file.

# %%
with open('aoc_friend_ids2.json','r') as f:
    aoc_friends_d = json.load(f)

# %% [markdown]
# Now we want to make a network of who follows whom.

# %%
friends_l = []

# Turn the dictionary into an edgelist
for user_id, friend_ids in aoc_friends_d.items():
    for friend_id in friend_ids:
        friends_l.append((str(user_id),str(friend_id)))
        
# Turn the list of dictionaries into a DataFrame
friends_df = pd.DataFrame(friends_l,columns=['user_id','friend_id'])

# Get the unique user_ids for AOC's friends
unique_friend_ids = friends_df['user_id'].unique()

# Just keep friends of AOC in the list
# Throw away friends of friends who aren't direct friends of AOC
subset_friends_df = friends_df[friends_df['friend_id'].isin(unique_friend_ids)]

# Print out number of edges remaining
print('Edges before: {:,}'.format(len(friends_df)),'\nEdges after: {:,}'.format(len(subset_friends_df)))
# Out:
# Edges before: 2,573,446
# Edges after: 160,041

# %% [markdown]
# Map the numeric user_id back to screen_name.

# %%
ids_to_screen_name_map = {str(user.id):user.screen_name for user in aoc_friends}
ids_to_screen_name_map['138203134'] = 'aoc'

# %% [markdown]
# Building on the [shared audience measure](http://faculty.washington.edu/kstarbi/Stewart_Starbird_Drawing_the_Lines_of_Contention-final.pdf) used by Stewart, *et al.* (2017), I computed [Jaccard coefficients](https://en.wikipedia.org/wiki/Jaccard_index) for the friend sets of each account. The intuituion here is that if two accounts are friends with all the same accounts, their score would be 1 while if two accounts had no friends in common, their score would be 0. This has the benefit of giving us a numerical weight to otherwise binary friend relationships: friend relations are "stronger" if they are more strongly embedded in a network with other overlapping friend relations and "weaker" if there is less overlap. This requires pair-wise evaluations of $1420*1419=2,014,980$ combinations, which takes about 20 minutes on my computer.

# %% [raw]
# jaccard_l = []
#
# for f1 in unique_friend_ids:
#     for f2 in unique_friend_ids:
#         if f1 != f2:
#             jaccard = len(set(aoc_friends_d[f1]) & set(aoc_friends_d[f2]))/len(set(aoc_friends_d[f1]) | set(aoc_friends_d[f2]))
#             jaccard_l.append({'user':f1,'friend':f2,'jaccard':jaccard})
#
# friend_jaccard_df = pd.DataFrame(jaccard_l)[['user','friend','jaccard']]
#
# friend_jaccard_df.to_csv('aoc_all_friend_jaccard.csv')

# %% [markdown]
# I've saved you the time and you can read in these pairwise Jaccard similarities from disk.

# %%
friend_jaccard_df = pd.read_csv('aoc_all_friend_jaccard.csv',index_col=0,
                                dtype={'user':str,'friend':str,'jaccard':float})

friend_jaccard_df.head()
# Out:
# /Users/briankeegan/anaconda/lib/python3.6/site-packages/numpy/lib/arraysetops.py:522: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#         user               friend   jaccard
# 0  138203134  1080854064567668736  0.059829
# 1  138203134   806906355214852096  0.048734
# 2  138203134  1079802482640019456  0.049516
# 3  138203134   713217283246530560  0.020949
# 4  138203134             78706973  0.028120

# %% [markdown]
# We can combine the `subset_friends_df` with `friend_jaccard_df` using pandas's [`merge`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html) command.

# %%
# Left-join the subset_friends and friend_jaccard DataFrames
friend_el = pd.merge(subset_friends_df,
                     friend_jaccard_df,
                     left_on=['user_id','friend_id'],
                     right_on=['user','friend'],how='left')

# Keep a few columns
friend_el = friend_el[['user','friend','jaccard']]

# Map the user_ids back to screen_names
friend_el['user'] = friend_el['user'].apply(str).map(ids_to_screen_name_map)
friend_el['friend'] = friend_el['friend'].apply(str).map(ids_to_screen_name_map)

# Save to disk
friend_el.to_csv('aoc_friends_edgelist.csv')

# Inspect
friend_el.tail()
# Out:
#               user       friend   jaccard
# 160036  DeanElmore   jsmooth995  0.006267
# 160037  DeanElmore         xeni  0.004169
# 160038  DeanElmore       lessig  0.005323
# 160039  DeanElmore  alex11shuck  0.058063
# 160040  DeanElmore     TEDTalks  0.011236

# %% [markdown]
# We are going to use the [`networkx`](https://networkx.github.io/documentation/stable/) (that should come with Anaconda by default) to convert this edgelist into a Graph object.

# %%
# Import networkx
import networkx as nx

# %% [markdown]
# This raw network is very dense: there are about 100 times more edges than nodes. A general heuristic for graph visualization is you want the number of nodes and edges to be about the same order of magnitude to prevent [overplotting](https://www.displayr.com/what-is-overplotting/).

# %%
g_dense = nx.from_pandas_edgelist(friend_el,source='user',target='friend',create_using=nx.Graph)
print("There are {0:,} nodes and {1:,} edges.".format(g_dense.number_of_nodes(),g_dense.number_of_edges()))
nx.write_gexf(g_dense,'aoc_all_friends.gexf')
# Out:
# There are 1,387 nodes and 130,580 edges.

# %% [markdown]
# The distribution of Jaccard scores we computed is very skewed. We can now use these similarity scores to filter out "weaker" edges. We are effectively throwing away all of the data to the left of the dashed line at the 95% percentile to help us with visualization.

# %%
ax = friend_el['jaccard'].plot(kind='hist',bins=np.logspace(-5,0,35))
ax.set_xscale('log')
ax.set_xlabel('Jaccard score')
ax.axvline(np.percentile(friend_el['jaccard'],95),c='k',ls='--')

# %% [markdown]
# Keep only the top 5% of edges for visualization purposes.

# %%
# Keep only the top 5% of edges by Jaccard coefficients
top_friend_el = friend_el[friend_el['jaccard'] > np.percentile(friend_el['jaccard'],95)]

# Write these top edges into the network
g = nx.from_pandas_edgelist(top_friend_el,source='user',target='friend',edge_attr=True,create_using=nx.Graph)
print("There are {0:,} nodes and {1:} edges.".format(g.number_of_nodes(),g.number_of_edges()))

# Save to disk
nx.write_gexf(g,'aoc_friends_filtered.gexf')
# Out:
# There are 726 nodes and 4753 edges.

# %% [markdown]
# I visualized the network below in [Gephi](https://gephi.org/). We see a distinctive community structure reflecting different identities like local organizations, journalists, national politicians, activist groups, *etc*.

# %%
from IPython.display import Image

Image('aoc_friends_filtered.png')

# %% [markdown]
# ## Using the streaming API
#
# We can also sit on Twitter's [Streaming API](https://developer.twitter.com/en/docs/tweets/sample-realtime/api-reference/get-statuses-sample) and get a sample of tweets that are produced in real time. The `.GetStreamSample()` method returns a [generator](https://wiki.python.org/moin/Generators), which is an advanced type of object that doesn't store any data *per se* but points to successive locations where you can find data. In this case, the generator points to where we can find the next tweet in the sample. For 10,000 tweets on a stream sampling approximately 1% of live tweets, this may take 2–3 minutes.

# %%
# Make the generator
stream = api.GetStreamSample()

# Make an empty list to store the tweet statuses
stream_list = []

# Start iterating through the stream
for status in stream:
    
    # As long as we have fewer than this many tweets
    if len(stream_list) < 1000:
        
        # And if it's not a delete status request
        if 'delete' not in status:
        
            # Add another tweet to our list
            stream_list.append(status)
        
    # Otherwise stop
    else:
        break
        
"There are {0:,} tweets from the stream.".format(len(stream_list))
# Out:
# 'There are 1,000 tweets from the stream.'

# %% [markdown]
# Look at one of our statuses.

# %%
stream_list[0]
# Out:
# {'created_at': 'Wed Feb 13 22:43:13 +0000 2019',
#  'id': 1095815686813712384,
#  'id_str': '1095815686813712384',
#  'text': 'ぼぶてぃる♪さん、あや♥さん、ここのえとわさん(@cabbageroll_0x0)といっしょにA・I・K・A・T・S・U!でごいっしょしました(*´ω｀*) https://t.co/cbMs921CTU',
#  'display_text_range': [0, 78],
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1012875342434918400,
#   'id_str': '1012875342434918400',
#   'name': 'まみこさん',
#   'screen_name': 'mamikostars80',
#   'location': None,
#   'url': None,
#   'description': 'まみこさんのアイドル活動(撮りカツ)用アカウントです。フレンズ名はハープスター(こと座の一等星の別名より)。アイコン:けちゃっぷさん(@ketchup_prpr)、ヘッダー:しおりんさん(@dollydevilsor)より☆',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 43,
#   'friends_count': 46,
#   'listed_count': 1,
#   'favourites_count': 625,
#   'statuses_count': 538,
#   'created_at': 'Sat Jun 30 01:47:54 +0000 2018',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': 'en',
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1012877185818873856/EiQchFpv_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1012877185818873856/EiQchFpv_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1012875342434918400/1534831095',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'cabbageroll_0x0',
#     'name': 'ぼぶてぃる♪ξ*畄ν畄)カレンダーガールで出棺したい',
#     'id': 140421182,
#     'id_str': '140421182',
#     'indices': [24, 40]}],
#   'symbols': [],
#   'media': [{'id': 1095815662247632896,
#     'id_str': '1095815662247632896',
#     'indices': [79, 102],
#     'media_url': 'http://pbs.twimg.com/media/DzUeifeUYAATOuA.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DzUeifeUYAATOuA.jpg',
#     'url': 'https://t.co/cbMs921CTU',
#     'display_url': 'pic.twitter.com/cbMs921CTU',
#     'expanded_url': 'https://twitter.com/mamikostars80/status/1095815686813712384/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#      'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]},
#  'extended_entities': {'media': [{'id': 1095815662247632896,
#     'id_str': '1095815662247632896',
#     'indices': [79, 102],
#     'media_url': 'http://pbs.twimg.com/media/DzUeifeUYAATOuA.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DzUeifeUYAATOuA.jpg',
#     'url': 'https://t.co/cbMs921CTU',
#     'display_url': 'pic.twitter.com/cbMs921CTU',
#     'expanded_url': 'https://twitter.com/mamikostars80/status/1095815686813712384/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#      'small': {'w': 510, 'h': 680, 'resize': 'fit'}}},
#    {'id': 1095815662256062464,
#     'id_str': '1095815662256062464',
#     'indices': [79, 102],
#     'media_url': 'http://pbs.twimg.com/media/DzUeifgVAAAOb9x.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DzUeifgVAAAOb9x.jpg',
#     'url': 'https://t.co/cbMs921CTU',
#     'display_url': 'pic.twitter.com/cbMs921CTU',
#     'expanded_url': 'https://twitter.com/mamikostars80/status/1095815686813712384/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#      'small': {'w': 510, 'h': 680, 'resize': 'fit'}}},
#    {'id': 1095815662251864064,
#     'id_str': '1095815662251864064',
#     'indices': [79, 102],
#     'media_url': 'http://pbs.twimg.com/media/DzUeiffU8AAeHuM.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DzUeiffU8AAeHuM.jpg',
#     'url': 'https://t.co/cbMs921CTU',
#     'display_url': 'pic.twitter.com/cbMs921CTU',
#     'expanded_url': 'https://twitter.com/mamikostars80/status/1095815686813712384/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#      'small': {'w': 510, 'h': 680, 'resize': 'fit'}}},
#    {'id': 1095815662243442688,
#     'id_str': '1095815662243442688',
#     'indices': [79, 102],
#     'media_url': 'http://pbs.twimg.com/media/DzUeifdUcAA9yrt.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/DzUeifdUcAA9yrt.jpg',
#     'url': 'https://t.co/cbMs921CTU',
#     'display_url': 'pic.twitter.com/cbMs921CTU',
#     'expanded_url': 'https://twitter.com/mamikostars80/status/1095815686813712384/photo/1',
#     'type': 'photo',
#     'sizes': {'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#      'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#      'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'ja',
#  'timestamp_ms': '1550097793664'}

# %% [markdown]
# Because these dictionaries represent raw JSON rather than cute `Status` objects, we need to adapt our loop from above that turns tweet statuses into a flat DataFrame. (I warned you!)

# %%
def tweet_cleaner(status):
    payload = {}
    payload['screen_name'] = status['user']['screen_name']
    payload['created'] = pd.to_datetime(status['created_at'])
    payload['retweets'] = status['retweet_count']
    payload['favorites'] = status['favorite_count']
    payload['id'] = status['id']
    payload['reply_screen_name'] = status['in_reply_to_screen_name']
    payload['reply_id'] = status['in_reply_to_status_id']
    payload['source'] = BeautifulSoup(status['source']).text
    payload['lang'] = status['lang']
    
    if status['place']:
        payload['place'] = status['place']['country']
    else:
        payload['place'] = None

    if len(status['entities']['user_mentions']) > 0:
        payload['user_mentions'] = '; '.join([m['screen_name'] for m in status['entities']['user_mentions']])
    else:
        payload['user_mentions'] = None

    if len(status['entities']['hashtags']) > 0:
        payload['hashtags'] = '; '.join([h['text'] for h in status['entities']['hashtags']])
    else:
        payload['hashtags'] = None

    # If an account retweets another account, we should store that information
    if 'retweeted_status' in status:
        rt_status = status['retweeted_status']
        if 'extended_tweet' in rt_status:
            payload['text'] = rt_status['extended_tweet']['full_text']
            if len(rt_status['extended_tweet']['entities']['hashtags']) > 0:
                payload['hashtags'] = '; '.join([h['text'] for h in rt_status['extended_tweet']['entities']['hashtags']])
            else:
                payload['hashtags'] = None
        else:
            try:
                payload['text'] = rt_status['text']
            except:
                payload['text'] = rt_status['full_text']
            if len(rt_status['entities']['hashtags']) > 0:
                payload['hashtags'] = '; '.join([h['text'] for h in rt_status['entities']['hashtags']])
            else:
                payload['hashtags'] = None
        payload['is_retweet'] = True
        payload['retweeted_screen_name'] = rt_status['user']['screen_name']
        payload['retweeted_created'] = rt_status['created_at']
        payload['retweeted_source'] = BeautifulSoup(rt_status['source']).text
        
    else:
        if status['truncated']:
            payload['text'] = status['extended_tweet']['full_text']
        else:
            try:
                payload['text'] = status['text']
            except:
                payload['text'] = status['full_text']
        payload['is_retweet'] = False
        payload['retweeted_screen_name'] = False
        payload['retweeted_created'] = False
        payload['retweeted_source'] = False

    return payload

# %% [markdown]
# Loop through our list of dictionaries (including the delete stream objects) and flatten the dictionaries out into something we can read into a DataFrame. Include some exception handling that will keep track of which tweets throw errors and prints out the first 50 of those tweet's index position in the `stream_list` for us to diagnose.

# %%
stream_statuses_flat = []
errors = []

for i,status in enumerate(stream_list):
    try:
        payload = tweet_cleaner(status)
        stream_statuses_flat.append(payload)
    except:
        errors.append(str(i))

if len(errors) == 0:
    print("There were no errors!")
else:
    print("There were errors at the following indices:", '; '.join(errors[:50]))
# Out:
# There were no errors!

# %% [markdown]
# Make our DataFrame, clean up some columns, and make some new ones.

# %%
stream_df = pd.DataFrame(stream_statuses_flat)
stream_df['created'] = pd.to_datetime(stream_df['created'])
stream_df['created'] = stream_df['created'].dt.tz_convert(None)
stream_df.tail()
# Out:
#                 created  favorites hashtags                   id  is_retweet  \
# 995 2019-02-13 22:43:36          0     None  1095815783278673920        True
# 996 2019-02-13 22:43:36          0     None  1095815783278628865        True
# 997 2019-02-13 22:43:36          0     None  1095815783274475521       False
# 998 2019-02-13 22:43:36          0     None  1095815783257702400       False
# 999 2019-02-13 22:43:36          0     None  1095815783291199488       False
#
#     lang place      reply_id reply_screen_name  \
# 995   en  None           NaN              None
# 996   en  None           NaN              None
# 997   en  None           NaN              None
# 998   es  None           NaN              None
# 999   pt  None  1.095815e+18     murilovgsouza
#
#                   retweeted_created retweeted_screen_name  \
# 995  Wed Feb 13 14:19:49 +0000 2019       SevilleCalculat
# 996  Tue Feb 12 04:47:16 +0000 2019        GabrielaYukito
# 997                           False                 False
# 998                           False                 False
# 999                           False                 False
#
#         retweeted_source  retweets     screen_name               source  \
# 995   Twitter for iPhone         0         SteRed5  Twitter for Android
# 996  Twitter for Android         0      _Shakirah_   Twitter for iPhone
# 997                False         0        shylean6   Twitter for iPhone
# 998                False         0    toschimattia   Twitter for iPhone
# 999                False         0  luanaaraujo280  Twitter for Android
#
#                                                   text  \
# 995  Alan Power - no action\nPaul McGinn - no actio...
# 996  I hate having one of these dreams. 😂 https://t...
# 997                                           Love you
# 998                                        Casinista 😂
# 999  @murilovgsouza @dudhadadd É foda. E não fico f...
#
#                 user_mentions
# 995           SevilleCalculat
# 996            GabrielaYukito
# 997                      None
# 998                      None
# 999  murilovgsouza; dudhadadd

# %% [markdown]
# Where are people writing their tweets in this sample?

# %%
stream_df['source'].value_counts().head(20)
# Out:
# Twitter for iPhone        383
# Twitter for Android       367
# Twitter Web Client        102
# Twitter Web App            29
# Twitter for iPad           17
# twittbot.net               14
# IFTTT                      10
# تطبيق قرآني                 8
# Curious Cat                 7
# TweetDeck                   7
# Facebook                    6
# Takane Shijou               4
# feather for iOS             3
# تطبيــق دعـــاء             2
# Twitcom - Comunidades       2
# on TheWorld                 2
# CareerArc 2.0               2
# 今日のツイライフ                    2
# Echoes Act2                 2
# WordPress.com               2
# Name: source, dtype: int64

# %% [markdown]
# What languages are these tweets in?

# %%
stream_df['lang'].value_counts().head(10)
# Out:
# en     363
# ja     170
# pt     109
# es      96
# und     70
# ar      55
# fr      25
# ko      18
# tr      16
# th      14
# Name: lang, dtype: int64

# %% [markdown]
# If a tweet is geolocated, where is it?

# %%
stream_df['place'].value_counts()
# Out:
# United States     5
# Egypt             2
# Italia            1
# 日本                1
# Canada            1
# Brasil            1
# Estados Unidos    1
# España            1
# België            1
# Argentina         1
# United Kingdom    1
# Name: place, dtype: int64

# %%
stream_df[stream_df['place'] == 'Estados Unidos']
# Out:
#                created  favorites hashtags                   id  is_retweet  \
# 16 2019-02-13 22:43:14          0     None  1095815690995478529       False
#
#    lang           place      reply_id reply_screen_name retweeted_created  \
# 16  und  Estados Unidos  1.095815e+18     clairearenass             False
#
#    retweeted_screen_name retweeted_source  retweets      screen_name  \
# 16                 False            False         0  iVictorManuel__
#
#                 source                                           text  \
# 16  Twitter for iPhone  @clairearenass @kbvnks_ Brrrrr @clairearenass
#
#                             user_mentions
# 16  clairearenass; kbvnks_; clairearenass

# %% [markdown]
# How many tweets are retweets?

# %%
stream_df['is_retweet'].value_counts()
# Out:
# True     500
# False    500
# Name: is_retweet, dtype: int64

# %% [markdown]
# How many tweets are replies?

# %%
stream_df['reply_id'].notnull().value_counts()
# Out:
# False    805
# True     195
# Name: reply_id, dtype: int64

# %% [markdown]
# Which users are getting a lot of retweets right now?

# %%
stream_df['retweeted_screen_name'].value_counts().head(20)
# Out:
# False              500
# Nintendo             9
# NintendoAmerica      5
# Comin4YaHBeanIE      2
# Complex              2
# frasesdebebada       2
# idolshelpffx         2
# ermame26             2
# rikakoikee           2
# Lilartoni            2
# Gatita_Kristal1      2
# FizzySodaWave        2
# BTS_twt              2
# louisyacvlrd         1
# Scaaaaaaarlet        1
# CauseWereGuys        1
# dassuenfer           1
# BTSLAB_twt           1
# yisucristwit         1
# Yoshiking_1116       1
# Name: retweeted_screen_name, dtype: int64

# %% [markdown]
# ### Filtered streams
#
# We can also filter the tweets in the stream. Here we only get tweets mentioning "Trump" and that have been auto-classified as written in English.

# %%
# Make the generator
filtered_stream = api.GetStreamFilter(track=['Trump'],languages=['en'])

# Make an empty list to store the tweet statuses
filtered_stream_list = []

# What time did we start?
start = time.time()

# Start iterating through the stream
for status in filtered_stream:
    
    # As long as we have fewer than this many tweets
    if len(filtered_stream_list) < 1000:
        
        # And if it's not a delete status request
        if 'delete' not in status:
        
            # Add another tweet to our list
            filtered_stream_list.append(status)
        
    # Otherwise stop
    else:
        break

# What time did we stop?
stop = time.time()
elapsed = stop - start

"There are {0:,} tweets from the stream after {1:.0f} seconds.".format(len(filtered_stream_list),elapsed)
# Out:
# 'There are 1,000 tweets from the stream after 35 seconds.'

# %% [markdown]
# Clean this up into a DataFrame.

# %%
filtered_stream_statuses_flat = []
filtered_errors = []

for i,status in enumerate(filtered_stream_list):
    try:
        payload = tweet_cleaner(status)
        filtered_stream_statuses_flat.append(payload)
    except:
        filtered_errors.append(str(i))

if len(filtered_errors) == 0:
    print("There were no errors!")
else:
    print("There were errors at the following indices:", '; '.join(filtered_errors[:50]))
    
filtered_stream_df = pd.DataFrame(filtered_stream_statuses_flat)
filtered_stream_df['created'] = pd.to_datetime(filtered_stream_df['created'])
filtered_stream_df['created'] = filtered_stream_df['created'].dt.tz_convert(None)
filtered_stream_df.tail()
# Out:
# There were no errors!
#                 created  favorites hashtags                   id  is_retweet  \
# 995 2019-02-13 22:52:28          0     None  1095818015315320832       False
# 996 2019-02-13 22:52:28          0     None  1095818014732312576        True
# 997 2019-02-13 22:52:28          0     None  1095818015617110016        True
# 998 2019-02-13 22:52:28          0     None  1095818015675953152        True
# 999 2019-02-13 22:52:28          0     None  1095818015893970944        True
#
#     lang place      reply_id reply_screen_name  \
# 995   en  None  1.095297e+18      JohnMurphy51
# 996   en  None           NaN              None
# 997   en  None           NaN              None
# 998   en  None           NaN              None
# 999   en  None           NaN              None
#
#                   retweeted_created retweeted_screen_name    retweeted_source  \
# 995                           False                 False               False
# 996  Wed Feb 13 21:02:36 +0000 2019         charliekirk11  Twitter for iPhone
# 997  Wed Feb 13 19:05:32 +0000 2019               RBReich  Twitter Web Client
# 998  Wed Feb 13 16:43:31 +0000 2019          repmarkpocan  Twitter Web Client
# 999  Wed Feb 13 22:14:47 +0000 2019            ananavarro    Twitter for iPad
#
#      retweets   screen_name               source  \
# 995         0  templemore85  Twitter for Android
# 996         0    trumpforNC  Twitter for Android
# 997         0     herrick_a   Twitter for iPhone
# 998         0   adamisalamb     Twitter for iPad
# 999         0         csinp   Twitter for iPhone
#
#                                                   text  user_mentions
# 995  @JohnMurphy51 I'm amazed they didn't ask Trump...   JohnMurphy51
# 996  Net worth before running for President:\n\nTru...  charliekirk11
# 997  To the conservative mind, socialism conjures u...        RBReich
# 998  President Trump couldn't go to Mar-a-Lago duri...   repmarkpocan
# 999  If you didn’t see this live, you must see this...     ananavarro

# %% [markdown]
# Let's measure the sentiment of the tweets in this filtered s ample and plot the distribution of their sentiment values.

# %%
# Compute the sentiment scores
filtered_stream_df['sentiment'] = filtered_stream_df['text'].apply(lambda x:sia.polarity_scores(x)['compound'])

# Plot the distribution
filtered_stream_df['sentiment'].plot(kind='hist',bins=20)

# %% [markdown]
# How many retweets in this sample?

# %%
filtered_stream_df['is_retweet'].value_counts()
# Out:
# True     795
# False    205
# Name: is_retweet, dtype: int64

# %% [markdown]
# Given the higher fraction of retweets, who is being retweeted?

# %%
filtered_stream_df['retweeted_screen_name'].value_counts().head(10)
# Out:
# False              205
# charliekirk11       32
# krassenstein        30
# TheLeadCNN          27
# ananavarro          20
# Jim_Jordan          16
# repmarkpocan        12
# realDonaldTrump     12
# MarkSimoneNY        11
# RealSaavedra         8
# Name: retweeted_screen_name, dtype: int64

# %% [markdown]
# ## Search API
#
# Twitter's [search API](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets) provides an endpoint to search for tweets matching a query for terms, accounts, hashtags, language, locations, and date ranges. This API endpoint has a rate limit of 180 requests per 15-minute window with 100 statuses per request: or 18,000 statuses per window or 72,000 statuses per hour.
#
# You can explore some of the search functionality through Twitter's [advanced search interface](https://twitter.com/search-advanced). Note that the [standard search API](https://developer.twitter.com/en/docs/tweets/search/overview/standard) only provides a limited access to sample of tweets in the past 7 days, you'll need to pay more to access [historical APIs](https://developer.twitter.com/en/docs/tutorials/choosing-historical-api.html).

# %%
api.rate_limit.resources
# Out:
# {'users': {'/users/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550093800}},
#  'statuses': {'/statuses/show/:id': {'limit': 900,
#    'remaining': 899,
#    'reset': 1550094210},
#   '/statuses/lookup': {'limit': 900, 'remaining': 898, 'reset': 1550094938},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 881,
#    'reset': 1550095411}},
#  'friends': {'/friends/list': {'limit': 15,
#    'remaining': 7,
#    'reset': 1550096241},
#   '/friends/ids': {'limit': 15, 'remaining': 14, 'reset': 1550096667}},
#  'followers': {'/followers/list': {'limit': 15,
#    'remaining': 14,
#    'reset': 1550096362}}}

# %%
query = api.GetSearch(term='aoc',count=100,lang='en',result_type='recent',return_json=True)

# %% [markdown]
# Loop through these 100 tweets.

# %%
search_statuses_flat = []
search_errors = []

for i,status in enumerate(query['statuses']):
    try:
        payload = tweet_cleaner(status)
        search_statuses_flat.append(payload)
    except:
        search_errors.append(str(i))

if len(search_errors) == 0:
    print("There were no errors!")
else:
    print("There were errors at the following indices:", '; '.join(search_errors[:50]))
    
search_df = pd.DataFrame(search_statuses_flat)
# search_df['created'] = pd.to_datetime(search_df['created'])
# search_df['created'] = search_df['created'].dt.tz_convert(None)
search_df.tail()
# Out:
# There were no errors!
#                      created  favorites hashtags                   id  \
# 95 2019-02-13 22:55:35+00:00          0     None  1095818799125655552
# 96 2019-02-13 22:55:35+00:00          0     None  1095818798299598848
# 97 2019-02-13 22:55:35+00:00          0      AOC  1095818797569720320
# 98 2019-02-13 22:55:34+00:00          0     None  1095818795770273792
# 99 2019-02-13 22:55:34+00:00          0     None  1095818795514560513
#
#     is_retweet lang place      reply_id reply_screen_name  \
# 95       False   en  None  1.095803e+18           nedryun
# 96        True   en  None           NaN              None
# 97       False   en  None           NaN              None
# 98        True   en  None           NaN              None
# 99        True   en  None           NaN              None
#
#                  retweeted_created retweeted_screen_name    retweeted_source  \
# 95                           False                 False               False
# 96  Wed Feb 13 19:16:14 +0000 2019                   AOC  Twitter for iPhone
# 97                           False                 False               False
# 98  Wed Feb 13 22:51:29 +0000 2019       JaniceTXBlessed  Twitter Web Client
# 99  Wed Feb 13 22:50:38 +0000 2019        mitchellamunoz  Twitter for iPhone
#
#     retweets      screen_name               source  \
# 95         0   BruceSilver136   Twitter for iPhone
# 96     20723  canamrindiudian   Twitter for iPhone
# 97         0      nanking2100   Twitter Web Client
# 98         2   hankentwhistle  Twitter for Android
# 99         1         bl_burch     Twitter for iPad
#
#                                                  text  \
# 95  @nedryun @Frenchmarine1 @AOC Her Islamist shar...
# 96  Shock doesn’t begin to cover it.\n\nToday I le...
# 97  😆😂🤣 THAT IS HYSTERICAL! I STILL do not know wh...
# 98  @Jali_Cat @IlhanMN @Ilhan @SpeakerPelosi @DNC ...
# 99  @AOC What’s the problem? Are you thinking of a...
#
#                                         user_mentions
# 95                        nedryun; Frenchmarine1; AOC
# 96                                                AOC
# 97                                        TheSteveKon
# 98  JaniceTXBlessed; Jali_Cat; IlhanMN; Ilhan; Spe...
# 99                                mitchellamunoz; AOC

# %% [markdown]
# Write a loop to try to get more tweets. The `query` dictionary includes a sub-dictionary under the "search_metadata" key that includes information about paginating to find the next set of results.

# %%
search_tweets = []

while True:
    # When to stop?
    if len(search_tweets) == 2500:
        break
    
    # Get the first set of tweets
    if len(search_tweets) == 0:
        query = api.GetSearch(term='aoc',count=100,lang='en',result_type='recent',return_json=True)
        search_tweets += query['statuses']
        
    # Keep getting tweets
    else:
        # Find the last tweet to use as a max_id
        max_id = search_tweets[-1]['id']
        
        # Get the next set of tweets
        query = api.GetSearch(term='aoc',count=100,lang='en',return_json=True,max_id=max_id - 1)
        
        # Add them to the list of tweets
        search_tweets += query['statuses']
        
print("There are {0:,} tweets in the collection.".format(len(search_tweets)))
# Out:
# There are 2,500 tweets in the collection.

# %%
search_statuses_flat = []
search_errors = []

for i,status in enumerate(search_tweets):
    try:
        payload = tweet_cleaner(status)
        search_statuses_flat.append(payload)
    except:
        search_errors.append(str(i))

if len(search_errors) == 0:
    print("There were no errors!")
else:
    print("There were errors at the following indices:", '; '.join(search_errors[:50]))
    
search_df = pd.DataFrame(search_statuses_flat)
search_df['created'] = pd.to_datetime(search_df['created'])
search_df['created'] = search_df['created'].dt.tz_convert(None)
search_df.tail()
# Out:
# There were no errors!
#                  created  favorites hashtags                   id  is_retweet  \
# 2495 2019-02-13 22:46:38          0     None  1095816546134441985        True
# 2496 2019-02-13 22:46:38          0     None  1095816545190793216        True
# 2497 2019-02-13 22:46:38          0    ampFW  1095816545111019521        True
# 2498 2019-02-13 22:46:38          2     None  1095816544003620865       False
# 2499 2019-02-13 22:46:37          0     None  1095816540480389121        True
#
#      lang place      reply_id reply_screen_name  \
# 2495   en  None           NaN              None
# 2496   en  None           NaN              None
# 2497   en  None           NaN              None
# 2498   en  None  1.095814e+18      KrangTNelson
# 2499   en  None           NaN              None
#
#                    retweeted_created retweeted_screen_name  \
# 2495  Wed Feb 13 19:16:14 +0000 2019                   AOC
# 2496  Wed Feb 13 19:29:46 +0000 2019       JoyceWhiteVance
# 2497  Wed Feb 13 18:20:10 +0000 2019          FreedomWorks
# 2498                           False                 False
# 2499  Wed Feb 13 19:16:14 +0000 2019                   AOC
#
#         retweeted_source  retweets    screen_name               source  \
# 2495  Twitter for iPhone     20746        babsbcd   Twitter for iPhone
# 2496    Twitter for iPad       590    CTrentham88  Twitter for Android
# 2497       Sprout Social        33    mel54732492  Twitter for Android
# 2498               False         0   sicktransitw      Twitter Web App
# 2499  Twitter for iPhone     20746  Samuraiturnip      Twitter Web App
#
#                                                    text  \
# 2495  Shock doesn’t begin to cover it.\n\nToday I le...
# 2496  @AOC .@AOC, Professor &amp; former head of the...
# 2497  .@AOC is trying to "whistle" past her atrociou...
# 2498  @KrangTNelson And AOC wants to make us like th...
# 2499  Shock doesn’t begin to cover it.\n\nToday I le...
#
#                   user_mentions
# 2495                        AOC
# 2496  JoyceWhiteVance; AOC; AOC
# 2497          FreedomWorks; AOC
# 2498               KrangTNelson
# 2499                        AOC

# %%
# Compute the sentiment scores
search_df['sentiment'] = search_df['text'].apply(lambda x:sia.polarity_scores(x)['compound'])

# Plot the distribution
search_df['sentiment'].plot(kind='hist',bins=20)

# %% [markdown]
# ## Detecting bot accounts using Bot-o-meter
#
# Botometer is a tool developed by [researchers at Indiana University](https://osome.iuni.iu.edu/) to evaluate the likelihood of a given account being a bot ([related paper](https://arxiv.org/abs/1703.03107)) based on features like user meta-data, friends, content, sentiment, network, and timing. They provide an API as well as a [Python wrapper](https://github.com/IUNetSci/botometer-python) to use API. At the terminal command line, you'll need to:
#
# `pip install botometer`
#
# You will also need to request an API key from this marketplace: https://rapidapi.com/OSoMe/api/botometer
#
# Once you've done all of this, you can start!

# %%
import botometer

botometer_api_key = '924e739af7msh78c742ea41f287dp121424jsnff240670ac73'

bom = botometer.Botometer(mashape_key=botometer_api_key,**twitter_keys)

# %% [markdown]
# We can check a single account to see the response object. [Documentation for these different response scores](https://market.mashape.com/OSoMe/botometer/overview#wiki-response-object), but the most relevant information is available under "scores" for both English-specific accounts and universal.

# %%
bom_result = bom.check_account('@realdonaldtrump')

bom_result
# Out:
# {'cap': {'english': 0.0012616932230026553, 'universal': 0.0017440333583248883},
#  'categories': {'content': 0.14075428846626595,
#   'friend': 0.09407699305084682,
#   'network': 0.10416612598937423,
#   'sentiment': 0.08670851966080818,
#   'temporal': 0.2636844399869036,
#   'user': 0.02392906059496764},
#  'display_scores': {'content': 0.7,
#   'english': 0.1,
#   'friend': 0.5,
#   'network': 0.5,
#   'sentiment': 0.4,
#   'temporal': 1.3,
#   'universal': 0.1,
#   'user': 0.1},
#  'scores': {'english': 0.025471598156045747,
#   'universal': 0.027614042942260764},
#  'user': {'id_str': '25073877', 'screen_name': 'realDonaldTrump'}}

# %% [markdown]
# For this account, there's only a 3% chance of this account being a bot.

# %%
bom_result['scores']
# Out:
# {'english': 0.025471598156045747, 'universal': 0.027614042942260764}

# %% [markdown]
# Botometer is limited to 2,000 requests per day per user. Let's get the bot scores for the most-active screen names in our `search_df` sample.

# %%
search_screen_name_count = search_df['screen_name'].value_counts()

top_search_screen_names = search_screen_name_count[search_screen_name_count > 3].index.tolist()
top_search_screen_names
# Out:
# ['DavisJFox',
#  'juliettetorrez',
#  'Social411Now',
#  'bootystank71469',
#  'West_Hypocrisy',
#  'katerin98849359',
#  'tacoshipsitall',
#  'faab64',
#  'charlesspires',
#  'MichaelM0r0n',
#  'Nmharley2',
#  'ROFLMAO2',
#  'gril887',
#  'tsay_youdon',
#  'kaisap112',
#  'NeverPocahontas']

# %% [markdown]
# Loop through these accounts and get the bot scores. This could take a few minutes.

# %%
top_search_screen_name_bots = bom.check_accounts_in(top_search_screen_names)

top_search_screen_name_bot_list = []

for screen_name, result in top_search_screen_name_bots:
    top_search_screen_name_bot_list.append({screen_name:result})

# %% [markdown]
# I've posted some bot scores for accounts to save us time.

# %%
with open('top_search_screen_name_bots.json','r') as f:
    top_search_screen_name_bot_list = json.load(f)

# %% [markdown]
# Clean up this data, turn it into a Pandas `Series`, and rank the top scores.

# %%
universal_scores = {}
for result in top_search_screen_name_bot_list:
    for screen_name,r in result.items():
        universal_scores[screen_name] = r['scores']['universal']

scores_s = pd.Series(universal_scores).sort_values(ascending=False)

scores_s.sort_values(ascending=False).head(20)
# Out:
# West_Hypocrisy     0.708113
# NeverPocahontas    0.433677
# Social411Now       0.393746
# MichaelM0r0n       0.318419
# gril887            0.318419
# katerin98849359    0.283782
# ROFLMAO2           0.236337
# Nmharley2          0.221796
# juliettetorrez     0.170132
# tacoshipsitall     0.138026
# tsay_youdon        0.138026
# DavisJFox          0.111167
# bootystank71469    0.103286
# charlesspires      0.082540
# faab64             0.044479
# kaisap112          0.037980
# dtype: float64

# %% [markdown]
# Plot the histogram of scores.

# %%
scores_s.plot(kind='hist',bins=10)

# %%
sue_user = api.GetUser(screen_name='West_Hypocrisy')

# %%
sue_user.created_at
# Out:
# 'Sun Aug 19 20:26:45 +0000 2012'

# %%
vars(sue_user)
# Out:
# {'param_defaults': {'contributors_enabled': None,
#   'created_at': None,
#   'default_profile': None,
#   'default_profile_image': None,
#   'description': None,
#   'email': None,
#   'favourites_count': None,
#   'followers_count': None,
#   'following': None,
#   'friends_count': None,
#   'geo_enabled': None,
#   'id': None,
#   'id_str': None,
#   'lang': None,
#   'listed_count': None,
#   'location': None,
#   'name': None,
#   'notifications': None,
#   'profile_background_color': None,
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': None,
#   'profile_banner_url': None,
#   'profile_image_url': None,
#   'profile_image_url_https': None,
#   'profile_link_color': None,
#   'profile_sidebar_border_color': None,
#   'profile_sidebar_fill_color': None,
#   'profile_text_color': None,
#   'profile_use_background_image': None,
#   'protected': None,
#   'screen_name': None,
#   'status': None,
#   'statuses_count': None,
#   'time_zone': None,
#   'url': None,
#   'utc_offset': None,
#   'verified': None,
#   'withheld_in_countries': None,
#   'withheld_scope': None},
#  'contributors_enabled': False,
#  'created_at': 'Sun Aug 19 20:26:45 +0000 2012',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': 'THE #WEST #FRANCE #SWISS #EU #UK  #LOBBYISTS & #CHINA TOO ,BACK CORRUPT & EVIL DICTATORS.    NO WONDER WHY #AFRICA IS POOR .      🙏🙏🙏PRES.#TRUMP PLEASE HELP ✝️.',
#  'email': None,
#  'favourites_count': 3709,
#  'followers_count': 23225,
#  'following': False,
#  'friends_count': 23839,
#  'geo_enabled': False,
#  'id': 768191449,
#  'id_str': '768191449',
#  'lang': 'en',
#  'listed_count': 14,
#  'location': 'Banana Republic',
#  'name': 'Hypocrisy of the West',
#  'notifications': False,
#  'profile_background_color': '000000',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/768191449/1494766643',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1055620094682906624/BHx6oQWP_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1055620094682906624/BHx6oQWP_normal.jpg',
#  'profile_link_color': '1B95E0',
#  'profile_sidebar_border_color': '000000',
#  'profile_sidebar_fill_color': '000000',
#  'profile_text_color': '000000',
#  'profile_use_background_image': False,
#  'protected': False,
#  'screen_name': 'West_Hypocrisy',
#  'status': Status(ID=1095822272634515457, Created=Wed Feb 13 23:09:23 +0000 2019, Text='RT @West_Hypocrisy: @jimmurphySF @loucharbon @KenRoth @FoxNews @CBS @NPR @BBC @Reuters @cspan Where r @UN , @hrw..etc.? Silence is complici…'),
#  'statuses_count': 2926,
#  'time_zone': None,
#  'url': 'https://t.co/I3lU8HFYzZ',
#  'utc_offset': None,
#  'verified': False,
#  'withheld_in_countries': None,
#  'withheld_scope': None,
#  '_json': {'id': 768191449,
#   'id_str': '768191449',
#   'name': 'Hypocrisy of the West',
#   'screen_name': 'West_Hypocrisy',
#   'location': 'Banana Republic',
#   'profile_location': None,
#   'description': 'THE #WEST #FRANCE #SWISS #EU #UK  #LOBBYISTS & #CHINA TOO ,BACK CORRUPT & EVIL DICTATORS.    NO WONDER WHY #AFRICA IS POOR .      🙏🙏🙏PRES.#TRUMP PLEASE HELP ✝️.',
#   'url': 'https://t.co/I3lU8HFYzZ',
#   'entities': {'url': {'urls': [{'url': 'https://t.co/I3lU8HFYzZ',
#       'expanded_url': 'https://www.youtube.com/watch?v=kfoDNFvOmeU',
#       'display_url': 'youtube.com/watch?v=kfoDNF…',
#       'indices': [0, 23]}]},
#    'description': {'urls': []}},
#   'protected': False,
#   'followers_count': 23225,
#   'friends_count': 23839,
#   'listed_count': 14,
#   'created_at': 'Sun Aug 19 20:26:45 +0000 2012',
#   'favourites_count': 3709,
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'verified': False,
#   'statuses_count': 2926,
#   'lang': 'en',
#   'status': {'created_at': 'Wed Feb 13 23:09:23 +0000 2019',
#    'id': 1095822272634515457,
#    'id_str': '1095822272634515457',
#    'full_text': 'RT @West_Hypocrisy: @jimmurphySF @loucharbon @KenRoth @FoxNews @CBS @NPR @BBC @Reuters @cspan Where r @UN , @hrw..etc.? Silence is complici…',
#    'truncated': False,
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'West_Hypocrisy',
#       'name': 'Hypocrisy of the West',
#       'id': 768191449,
#       'id_str': '768191449',
#       'indices': [3, 18]},
#      {'screen_name': 'jimmurphySF',
#       'name': 'Jim Murphy',
#       'id': 22574178,
#       'id_str': '22574178',
#       'indices': [20, 32]},
#      {'screen_name': 'loucharbon',
#       'name': 'louis charbonneau',
#       'id': 38224970,
#       'id_str': '38224970',
#       'indices': [33, 44]},
#      {'screen_name': 'KenRoth',
#       'name': 'Kenneth Roth',
#       'id': 17839398,
#       'id_str': '17839398',
#       'indices': [45, 53]},
#      {'screen_name': 'FoxNews',
#       'name': 'Fox News',
#       'id': 1367531,
#       'id_str': '1367531',
#       'indices': [54, 62]},
#      {'screen_name': 'CBS',
#       'name': 'CBS',
#       'id': 97739866,
#       'id_str': '97739866',
#       'indices': [63, 67]},
#      {'screen_name': 'NPR',
#       'name': 'NPR',
#       'id': 5392522,
#       'id_str': '5392522',
#       'indices': [68, 72]},
#      {'screen_name': 'BBC',
#       'name': 'BBC',
#       'id': 19701628,
#       'id_str': '19701628',
#       'indices': [73, 77]},
#      {'screen_name': 'Reuters',
#       'name': 'Reuters Top News',
#       'id': 1652541,
#       'id_str': '1652541',
#       'indices': [78, 86]},
#      {'screen_name': 'cspan',
#       'name': 'CSPAN',
#       'id': 15675138,
#       'id_str': '15675138',
#       'indices': [87, 93]},
#      {'screen_name': 'UN',
#       'name': 'United Nations',
#       'id': 14159148,
#       'id_str': '14159148',
#       'indices': [102, 105]},
#      {'screen_name': 'hrw',
#       'name': 'Human Rights Watch',
#       'id': 14700316,
#       'id_str': '14700316',
#       'indices': [108, 112]}],
#     'urls': []},
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'retweeted_status': {'created_at': 'Sat Jun 17 21:01:08 +0000 2017',
#     'id': 876182950836150272,
#     'id_str': '876182950836150272',
#     'full_text': '@jimmurphySF @loucharbon @KenRoth @FoxNews @CBS @NPR @BBC @Reuters @cspan Where r @UN , @hrw..etc.? Silence is complicit !  https://t.co/WMUAzDwQWr @StateDept @nikkihaley @KenRoth @MatthewRycroft1  @antonioguterres',
#     'truncated': False,
#     'display_text_range': [74, 214],
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'user_mentions': [{'screen_name': 'jimmurphySF',
#        'name': 'Jim Murphy',
#        'id': 22574178,
#        'id_str': '22574178',
#        'indices': [0, 12]},
#       {'screen_name': 'loucharbon',
#        'name': 'louis charbonneau',
#        'id': 38224970,
#        'id_str': '38224970',
#        'indices': [13, 24]},
#       {'screen_name': 'KenRoth',
#        'name': 'Kenneth Roth',
#        'id': 17839398,
#        'id_str': '17839398',
#        'indices': [25, 33]},
#       {'screen_name': 'FoxNews',
#        'name': 'Fox News',
#        'id': 1367531,
#        'id_str': '1367531',
#        'indices': [34, 42]},
#       {'screen_name': 'CBS',
#        'name': 'CBS',
#        'id': 97739866,
#        'id_str': '97739866',
#        'indices': [43, 47]},
#       {'screen_name': 'NPR',
#        'name': 'NPR',
#        'id': 5392522,
#        'id_str': '5392522',
#        'indices': [48, 52]},
#       {'screen_name': 'BBC',
#        'name': 'BBC',
#        'id': 19701628,
#        'id_str': '19701628',
#        'indices': [53, 57]},
#       {'screen_name': 'Reuters',
#        'name': 'Reuters Top News',
#        'id': 1652541,
#        'id_str': '1652541',
#        'indices': [58, 66]},
#       {'screen_name': 'cspan',
#        'name': 'CSPAN',
#        'id': 15675138,
#        'id_str': '15675138',
#        'indices': [67, 73]},
#       {'screen_name': 'UN',
#        'name': 'United Nations',
#        'id': 14159148,
#        'id_str': '14159148',
#        'indices': [82, 85]},
#       {'screen_name': 'hrw',
#        'name': 'Human Rights Watch',
#        'id': 14700316,
#        'id_str': '14700316',
#        'indices': [88, 92]},
#       {'screen_name': 'StateDept',
#        'name': 'Department of State',
#        'id': 9624742,
#        'id_str': '9624742',
#        'indices': [148, 158]},
#       {'screen_name': 'NikkiHaley',
#        'name': 'Nikki Haley',
#        'id': 1079776144524754944,
#        'id_str': '1079776144524754944',
#        'indices': [159, 170]},
#       {'screen_name': 'KenRoth',
#        'name': 'Kenneth Roth',
#        'id': 17839398,
#        'id_str': '17839398',
#        'indices': [171, 179]},
#       {'screen_name': 'MatthewRycroft1',
#        'name': 'Matthew Rycroft',
#        'id': 504899447,
#        'id_str': '504899447',
#        'indices': [180, 196]},
#       {'screen_name': 'antonioguterres',
#        'name': 'António Guterres',
#        'id': 811229675758505984,
#        'id_str': '811229675758505984',
#        'indices': [198, 214]}],
#      'urls': [],
#      'media': [{'id': 842883113139273729,
#        'id_str': '842883113139273729',
#        'indices': [124, 147],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/842883113139273729/pu/img/-XPSTqQdtu-9opkm.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/842883113139273729/pu/img/-XPSTqQdtu-9opkm.jpg',
#        'url': 'https://t.co/WMUAzDwQWr',
#        'display_url': 'pic.twitter.com/WMUAzDwQWr',
#        'expanded_url': 'https://twitter.com/WestCameroons/status/842883237710106624/video/1',
#        'type': 'photo',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 400, 'h': 224, 'resize': 'fit'},
#         'medium': {'w': 400, 'h': 224, 'resize': 'fit'},
#         'large': {'w': 400, 'h': 224, 'resize': 'fit'}},
#        'source_status_id': 842883237710106624,
#        'source_status_id_str': '842883237710106624',
#        'source_user_id': 821806139172122627,
#        'source_user_id_str': '821806139172122627'}]},
#     'extended_entities': {'media': [{'id': 842883113139273729,
#        'id_str': '842883113139273729',
#        'indices': [124, 147],
#        'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/842883113139273729/pu/img/-XPSTqQdtu-9opkm.jpg',
#        'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/842883113139273729/pu/img/-XPSTqQdtu-9opkm.jpg',
#        'url': 'https://t.co/WMUAzDwQWr',
#        'display_url': 'pic.twitter.com/WMUAzDwQWr',
#        'expanded_url': 'https://twitter.com/WestCameroons/status/842883237710106624/video/1',
#        'type': 'video',
#        'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#         'small': {'w': 400, 'h': 224, 'resize': 'fit'},
#         'medium': {'w': 400, 'h': 224, 'resize': 'fit'},
#         'large': {'w': 400, 'h': 224, 'resize': 'fit'}},
#        'source_status_id': 842883237710106624,
#        'source_status_id_str': '842883237710106624',
#        'source_user_id': 821806139172122627,
#        'source_user_id_str': '821806139172122627',
#        'video_info': {'aspect_ratio': [25, 14],
#         'duration_millis': 16440,
#         'variants': [{'bitrate': 256000,
#           'content_type': 'video/mp4',
#           'url': 'https://video.twimg.com/ext_tw_video/842883113139273729/pu/vid/320x180/aVUSvgDNLTWXZV5C.mp4'},
#          {'content_type': 'application/x-mpegURL',
#           'url': 'https://video.twimg.com/ext_tw_video/842883113139273729/pu/pl/tmXRAxexuTlnlT4Q.m3u8'}]},
#        'additional_media_info': {'monetizable': False}}]},
#     'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#     'in_reply_to_status_id': 876179154210873345,
#     'in_reply_to_status_id_str': '876179154210873345',
#     'in_reply_to_user_id': 768191449,
#     'in_reply_to_user_id_str': '768191449',
#     'in_reply_to_screen_name': 'West_Hypocrisy',
#     'geo': None,
#     'coordinates': None,
#     'place': None,
#     'contributors': None,
#     'is_quote_status': False,
#     'retweet_count': 56,
#     'favorite_count': 41,
#     'favorited': False,
#     'retweeted': False,
#     'possibly_sensitive': False,
#     'lang': 'en'},
#    'is_quote_status': False,
#    'retweet_count': 56,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'contributors_enabled': False,
#   'is_translator': False,
#   'is_translation_enabled': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1055620094682906624/BHx6oQWP_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1055620094682906624/BHx6oQWP_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/768191449/1494766643',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'has_extended_profile': False,
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': False,
#   'follow_request_sent': False,
#   'notifications': False,
#   'translator_type': 'none'}}

# %% [markdown]
# Let's look at the user timeline for one of these accounts.

# %%
# Start with the list of the 200 most-recent tweets
bot_timeline_tweets = api.GetUserTimeline(screen_name='West_Hypocrisy',count=200,include_rts=True)

# Initialize a counter so we don't go overboard with our requests
request_counter = 1

# While our request counter hasn't gone past 16
while request_counter < 17:
    # Get the most oldest tweet id
    final_status_id = bot_timeline_tweets[-1].id
    
    # Pass this tweet ID into the max_id parameter, minus 1 so we don't duplicate it
    bot_timeline_tweets += api.GetUserTimeline(screen_name='West_Hypocrisy',count=200,include_rts=True,max_id=final_status_id-1)
    
    # Increment our request_counter
    request_counter += 1

# %% [markdown]
# How many tweets?

# %%
"There are {0:,} tweets.".format(len(bot_timeline_tweets))
# Out:
# 'There are 2,172 tweets.'

# %% [markdown]
# Re-use our code from above to flatten.

# %%
bot_statuses_list = []

for status in bot_timeline_tweets:
    if type(status) == twitter.models.Status:
        payload = {}
        payload['screen_name'] = status.user.screen_name
        payload['created'] = pd.to_datetime(status.created_at)
        payload['retweets'] = status.retweet_count
        payload['favorites'] = status.favorite_count
        payload['id'] = status.id
        payload['reply_screen_name'] = status.in_reply_to_screen_name
        payload['reply_id'] = status.in_reply_to_status_id
        payload['source'] = BeautifulSoup(status.source).text
        
        if len(status.user_mentions) > 0:
            payload['user_mentions'] = '; '.join([m.screen_name for m in status.user_mentions])
        else:
            payload['user_mentions'] = None
            
        if len(status.hashtags) > 0:
            payload['hashtags'] = '; '.join([h.text for h in status.hashtags])
        else:
            payload['hashtags'] = None
        
        # If an account retweets another account, we should store that information
        if status.retweeted_status == None:
            payload['text'] = status.full_text
            payload['is_retweet'] = False
            payload['retweeted_screen_name'] = False
            payload['retweeted_created'] = False
        else:
            payload['text'] = status.retweeted_status.full_text
            payload['is_retweet'] = True
            payload['retweeted_screen_name'] = status.retweeted_status.user.screen_name
            payload['retweeted_created'] = status.retweeted_status.created_at
            payload['retweeted_source'] = BeautifulSoup(status.retweeted_status.source).text
            if len(status.retweeted_status.hashtags) > 0:
                payload['hashtags'] = '; '.join([h.text for h in status.retweeted_status.hashtags])
            else:
                payload['hashtags'] = None
        
        bot_statuses_list.append(payload)
        
bot_timeline_df = pd.DataFrame(bot_statuses_list)

# %% [markdown]
# Clean up our DataFrame.

# %%
bot_timeline_df['timestamp'] = pd.to_datetime(bot_timeline_df['created'])
bot_timeline_df['timestamp'] = pd.to_datetime(bot_timeline_df['timestamp'])
bot_timeline_df['timestamp'] = bot_timeline_df['timestamp'].dt.tz_convert(None)

bot_timeline_df['date'] = bot_timeline_df['timestamp'].apply(lambda x:x.date())
bot_timeline_df['weekday'] = bot_timeline_df['timestamp'].apply(lambda x:x.weekday())
bot_timeline_df['hour'] = bot_timeline_df['timestamp'].apply(lambda x:x.hour)

bot_timeline_df['sentiment'] = bot_timeline_df['text'].apply(lambda x:sia.polarity_scores(x)['compound'])

bot_timeline_df.head()
# Out:
#                     created  favorites  \
# 0 2019-02-13 23:09:02+00:00          0
# 1 2019-02-13 23:08:56+00:00          0
# 2 2019-02-13 23:08:50+00:00          0
# 3 2019-02-13 23:08:43+00:00          0
# 4 2019-02-13 23:08:35+00:00          0
#
#                                             hashtags                   id  \
# 0  Cameroon; Africa; Ambazonia; humanrights; Came...  1095822184684142594
# 1                                   Media; hypocrisy  1095822156955561984
# 2  slaughter; tortures; Cameroon; Africa; UN; Fra...  1095822130846019591
# 3  Cameroon; MauriceKamto; PaulBiya; AfricanUnion...  1095822102068891650
# 4         France; Macron; African; Brexit; Francexit  1095822071177904133
#
#    is_retweet  reply_id reply_screen_name               retweeted_created  \
# 0        True       NaN              None  Mon Jul 02 02:50:04 +0000 2018
# 1        True       NaN              None  Fri Jan 25 01:40:01 +0000 2019
# 2        True       NaN              None  Sun May 20 01:27:23 +0000 2018
# 3        True       NaN              None  Tue Jan 29 09:31:10 +0000 2019
# 4        True       NaN              None  Sun Jan 20 05:04:02 +0000 2019
#
#   retweeted_screen_name    retweeted_source  retweets     screen_name  \
# 0        West_Hypocrisy  Twitter Web Client        50  West_Hypocrisy
# 1        West_Hypocrisy  Twitter Web Client        51  West_Hypocrisy
# 2        West_Hypocrisy  Twitter Web Client        31  West_Hypocrisy
# 3         Cooloo_Africa  Twitter Web Client         6  West_Hypocrisy
# 4        West_Hypocrisy  Twitter Web Client       154  West_Hypocrisy
#
#                source                                               text  \
# 0  Twitter Web Client  #Cameroon #Africa\n\n https://t.co/oL79SqM4hU ...
# 1  Twitter Web Client  Italy Accuses France of ‘Impoverishing Africa’...
# 2  Twitter Web Client  @innercitypress @joyce_sah @judithnwana @BohHe...
# 3  Twitter Web Client  Cameroonian opposition leader arrested\n#Camer...
# 4  Twitter Web Client  @theresa_may This is #France under #Macron.\n\...
#
#                                        user_mentions           timestamp  \
# 0                                     West_Hypocrisy 2019-02-13 23:09:02
# 1                                     West_Hypocrisy 2019-02-13 23:08:56
# 2  West_Hypocrisy; innercitypress; joyce_sah; jud... 2019-02-13 23:08:50
# 3                                      Cooloo_Africa 2019-02-13 23:08:43
# 4                        West_Hypocrisy; theresa_may 2019-02-13 23:08:35
#
#          date  weekday  hour  sentiment
# 0  2019-02-13        2    23     0.0258
# 1  2019-02-13        2    23    -0.6608
# 2  2019-02-13        2    23     0.3311
# 3  2019-02-13        2    23    -0.4767
# 4  2019-02-13        2    23     0.0000

# %% [markdown]
# Every single one of the tweets from this account is a retweet.

# %%
bot_timeline_df['is_retweet'].value_counts()
# Out:
# True     1110
# False    1062
# Name: is_retweet, dtype: int64

# %% [markdown]
# All of these tweets come from a "Twitter for Android" source.

# %%
bot_timeline_df['source'].value_counts()
# Out:
# Twitter Web Client      2146
# Twitter for Websites      22
# Shareaholic.com            4
# Name: source, dtype: int64

# %% [markdown]
# Who are the account they are retweeting? Prominent conservatives.

# %%
bot_timeline_df['retweeted_screen_name'].value_counts().head(10)
# Out:
# False              1062
# West_Hypocrisy      483
# innercitypress       75
# SAVE__AMERICA        42
# Smith_JeffreyT       20
# brett_l_carter       19
# WestCameroons        18
# AlbertNchinda        15
# realDonaldTrump      14
# V_of_Europe           6
# Name: retweeted_screen_name, dtype: int64

# %% [markdown]
# What is the distribution of the time between tweets? The vast majority of the time between tweets happen less than 60 seconds apart.

# %%
tweet_latencies = bot_timeline_df['timestamp'].sort_values().diff()/pd.Timedelta(1,'s')
ax = tweet_latencies.plot(kind='hist',bins=np.logspace(1,4,25))
ax.set_xscale('log')
ax.axvline(60,c='k',ls='--')
ax.axvline(3600,c='k',ls='--')
ax.set_ylim((0,250))
ax.set_xlabel('Seconds between tweets')
# Out:
# Text(0.5, 0, 'Seconds between tweets')

# %% [markdown]
# Given that all this account's tweets are retweets, what is the distribution of time from original tweet to its retweet? Mostly after an hour but within a day.

# %%
_s = (pd.to_datetime(bot_timeline_df['created']) - pd.to_datetime(bot_timeline_df['retweeted_created']))/pd.Timedelta(1,'s')
ax = _s.plot(kind='hist',bins=np.logspace(1,7,25))
ax.axvline(60,c='k',ls='--')
ax.axvline(3600,c='k',ls='--')
ax.axvline(86400,c='k',ls='--')
ax.set_xscale('log')
ax.set_xlabel('Seconds between tweets')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-147-4940cb6e9805> in <module>
# ----> 1 _s = (pd.to_datetime(bot_timeline_df['created']) - pd.to_datetime(bot_timeline_df['retweeted_created']))/pd.Timedelta(1,'s')
#       2 ax = _s.plot(kind='hist',bins=np.logspace(1,7,25))
#       3 ax.axvline(60,c='k',ls='--')
#       4 ax.axvline(3600,c='k',ls='--')
#       5 ax.axvline(86400,c='k',ls='--')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     590         else:
#     591             from pandas import Series
# --> 592             values = convert_listlike(arg._values, True, format)
#     593             result = Series(values, index=arg.index, name=arg.name)
#     594     elif isinstance(arg, (ABCDataFrame, compat.MutableMapping)):
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, box, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     300             arg, dayfirst=dayfirst, yearfirst=yearfirst,
#     301             utc=utc, errors=errors, require_iso8601=require_iso8601,
# --> 302             allow_object=True)
#     303
#     304     if tz_parsed is not None:
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1855             dayfirst=dayfirst,
#    1856             yearfirst=yearfirst,
# -> 1857             require_iso8601=require_iso8601
#    1858         )
#    1859     except ValueError as e:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: <class 'bool'> is not convertible to datetime

# %% [markdown]
# I like to make a "temporal fingerprint" of a user account to see what days of the week and hours of the day a user is active. This user appears to be most active on Wednesday afternoons. But this appears to be much more random than I would expect (weekends *vs*. weekdays, nighttime *vs*. daytime, *etc*.).

# %%
ct = pd.crosstab(bot_timeline_df['weekday'],bot_timeline_df['hour']).fillna(0)

f,ax = plt.subplots(1,1,figsize=(12,3))
sb.heatmap(ct,square=True,cmap='rainbow',ax=ax,annot=True,fmt='.0f')

ax.set_yticklabels(['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],rotation=0)
ax.set_ylabel(None)
# Out:
# Text(87.0, 0.5, '')

# %% [markdown]
# Distribution of sentiment scores.

# %%
bot_timeline_df['sentiment'].plot(kind='hist',bins=20)

# %% [markdown]
# Sentiment scores over time.

# %%
f,ax = plt.subplots(1,1,figsize=(12,4))
_s = bot_timeline_df.groupby('date').agg({'sentiment':'mean'})
_s = _s.reindex(pd.date_range(_s.index.min(),_s.index.max()),fill_value=0)
_s['sentiment'].plot(ax=ax)
ax.axhline(0,c='k',ls='--',alpha=.5)

# %% [markdown]
# ## Get status replies

# %%
aoc_status = api.GetStatus(1095765485319319553)

# %%
vars(aoc_status)
# Out:
# {'param_defaults': {'contributors': None,
#   'coordinates': None,
#   'created_at': None,
#   'current_user_retweet': None,
#   'favorite_count': None,
#   'favorited': None,
#   'full_text': None,
#   'geo': None,
#   'hashtags': None,
#   'id': None,
#   'id_str': None,
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_user_id': None,
#   'lang': None,
#   'location': None,
#   'media': None,
#   'place': None,
#   'possibly_sensitive': None,
#   'quoted_status': None,
#   'quoted_status_id': None,
#   'quoted_status_id_str': None,
#   'retweet_count': None,
#   'retweeted': None,
#   'retweeted_status': None,
#   'scopes': None,
#   'source': None,
#   'text': None,
#   'truncated': None,
#   'urls': None,
#   'user': None,
#   'user_mentions': None,
#   'withheld_copyright': None,
#   'withheld_in_countries': None,
#   'withheld_scope': None},
#  'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed Feb 13 19:23:44 +0000 2019',
#  'current_user_retweet': None,
#  'favorite_count': 25284,
#  'favorited': False,
#  'full_text': 'BREAKING NEWS from @SHODesusAndMero &amp; @AOC https://t.co/3ELkgjcFGS',
#  'geo': None,
#  'hashtags': [],
#  'id': 1095765485319319553,
#  'id_str': '1095765485319319553',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_user_id': None,
#  'lang': 'en',
#  'location': None,
#  'media': [Media(ID=1095734227956420609, Type=video, DisplayURL='pic.twitter.com/3ELkgjcFGS')],
#  'place': None,
#  'possibly_sensitive': False,
#  'quoted_status': None,
#  'quoted_status_id': None,
#  'quoted_status_id_str': None,
#  'retweet_count': 5925,
#  'retweeted': False,
#  'retweeted_status': None,
#  'scopes': None,
#  'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#  'text': None,
#  'truncated': False,
#  'urls': [],
#  'user': User(ID=14594844, ScreenName=desusnice),
#  'user_mentions': [User(ID=1067826316622405633, ScreenName=SHODesusAndMero),
#   User(ID=138203134, ScreenName=AOC)],
#  'withheld_copyright': None,
#  'withheld_in_countries': None,
#  'withheld_scope': None,
#  'tweet_mode': 'extended',
#  '_json': {'created_at': 'Wed Feb 13 19:23:44 +0000 2019',
#   'id': 1095765485319319553,
#   'id_str': '1095765485319319553',
#   'full_text': 'BREAKING NEWS from @SHODesusAndMero &amp; @AOC https://t.co/3ELkgjcFGS',
#   'truncated': False,
#   'display_text_range': [0, 46],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'SHODesusAndMero',
#      'name': 'Desus & Mero on SHOWTIME',
#      'id': 1067826316622405633,
#      'id_str': '1067826316622405633',
#      'indices': [19, 35]},
#     {'screen_name': 'AOC',
#      'name': 'Alexandria Ocasio-Cortez',
#      'id': 138203134,
#      'id_str': '138203134',
#      'indices': [42, 46]}],
#    'urls': [],
#    'media': [{'id': 1095734227956420609,
#      'id_str': '1095734227956420609',
#      'indices': [47, 70],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1095734227956420609/img/brNxr94W1LFaxRA4.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1095734227956420609/img/brNxr94W1LFaxRA4.jpg',
#      'url': 'https://t.co/3ELkgjcFGS',
#      'display_url': 'pic.twitter.com/3ELkgjcFGS',
#      'expanded_url': 'https://twitter.com/desusnice/status/1095765485319319553/video/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_user_id': 1067826316622405633,
#      'source_user_id_str': '1067826316622405633'}]},
#   'extended_entities': {'media': [{'id': 1095734227956420609,
#      'id_str': '1095734227956420609',
#      'indices': [47, 70],
#      'media_url': 'http://pbs.twimg.com/amplify_video_thumb/1095734227956420609/img/brNxr94W1LFaxRA4.jpg',
#      'media_url_https': 'https://pbs.twimg.com/amplify_video_thumb/1095734227956420609/img/brNxr94W1LFaxRA4.jpg',
#      'url': 'https://t.co/3ELkgjcFGS',
#      'display_url': 'pic.twitter.com/3ELkgjcFGS',
#      'expanded_url': 'https://twitter.com/desusnice/status/1095765485319319553/video/1',
#      'type': 'video',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 383, 'resize': 'fit'},
#       'large': {'w': 1280, 'h': 720, 'resize': 'fit'}},
#      'source_user_id': 1067826316622405633,
#      'source_user_id_str': '1067826316622405633',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 30030,
#       'variants': [{'bitrate': 288000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1095734227956420609/vid/320x180/SdO-YWZQpLilvd0x.mp4?tag=9'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1095734227956420609/vid/640x360/gaBgcxM9AjEXBhtx.mp4?tag=9'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/amplify_video/1095734227956420609/pl/LXjs0Hv4s2nyNXzn.m3u8?tag=9'},
#        {'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/amplify_video/1095734227956420609/vid/1280x720/9RixmxcK9ea9cvy4.mp4?tag=9'}]},
#      'ext_alt_text': None,
#      'additional_media_info': {'monetizable': False,
#       'source_user': {'id': 1067826316622405633,
#        'id_str': '1067826316622405633',
#        'name': 'Desus & Mero on SHOWTIME',
#        'screen_name': 'SHODesusAndMero',
#        'location': 'Bronx, NY',
#        'description': '#DESUSandMERO coming to @Showtime Thursday, Feb 21, at 11/10c. 🎨 #BodegaHive 💪 #ShowtimeLateNight',
#        'url': 'https://t.co/Z4fAsQaTKI',
#        'entities': {'url': {'urls': [{'url': 'https://t.co/Z4fAsQaTKI',
#            'expanded_url': 'https://s.sho.com/DesusandMero',
#            'display_url': 's.sho.com/DesusandMero',
#            'indices': [0, 23]}]},
#         'description': {'urls': []}},
#        'protected': False,
#        'followers_count': 21307,
#        'friends_count': 38,
#        'listed_count': 40,
#        'created_at': 'Wed Nov 28 17:03:27 +0000 2018',
#        'favourites_count': 1608,
#        'utc_offset': None,
#        'time_zone': None,
#        'geo_enabled': False,
#        'verified': True,
#        'statuses_count': 175,
#        'lang': 'en',
#        'contributors_enabled': False,
#        'is_translator': False,
#        'is_translation_enabled': False,
#        'profile_background_color': '000000',
#        'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#        'profile_background_tile': False,
#        'profile_image_url': 'http://pbs.twimg.com/profile_images/1086330636347101184/O4jAE1bq_normal.jpg',
#        'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1086330636347101184/O4jAE1bq_normal.jpg',
#        'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1067826316622405633/1549059124',
#        'profile_image_extensions_alt_text': None,
#        'profile_banner_extensions_alt_text': None,
#        'profile_link_color': '000000',
#        'profile_sidebar_border_color': '000000',
#        'profile_sidebar_fill_color': '000000',
#        'profile_text_color': '000000',
#        'profile_use_background_image': False,
#        'has_extended_profile': False,
#        'default_profile': False,
#        'default_profile_image': False,
#        'following': False,
#        'follow_request_sent': False,
#        'notifications': False,
#        'translator_type': 'none'}}}]},
#   'source': '<a href="https://studio.twitter.com" rel="nofollow">Twitter Media Studio</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 14594844,
#    'id_str': '14594844',
#    'name': 'Desus Nice',
#    'screen_name': 'desusnice',
#    'location': 'BRONX ✈️✈️ ✈️ NYC ✈️✈️ DUBAI',
#    'description': '@ShoDesusandMero on @showtime  | @Bodegaboys on Itunes | Gottlieb in @neoyokio on @netflix | IG: desusnice',
#    'url': 'http://t.co/eW3E4xM2uE',
#    'entities': {'url': {'urls': [{'url': 'http://t.co/eW3E4xM2uE',
#        'expanded_url': 'http://desusexmachina.tumblr.com/',
#        'display_url': 'desusexmachina.tumblr.com',
#        'indices': [0, 22]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 890969,
#    'friends_count': 1593,
#    'listed_count': 2569,
#    'created_at': 'Wed Apr 30 02:36:30 +0000 2008',
#    'favourites_count': 9118,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 79283,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1719789976/tumblr_lv8nwnDueN1qg861n_normal.jpeg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1719789976/tumblr_lv8nwnDueN1qg861n_normal.jpeg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14594844/1383860071',
#    'profile_image_extensions_alt_text': None,
#    'profile_banner_extensions_alt_text': None,
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'regular'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 5925,
#   'favorite_count': 25284,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'possibly_sensitive_appealable': False,
#   'lang': 'en'}}

# %%
replies = api.GetReplies(count=20)

# %%
unquote('near%3A"Boulder%2C%20CO"%20within%3A15mi')
# Out:
# 'near:"Boulder, CO" within:15mi'

# %%
quote('near:"Broomfield, CO" within:30mi')
# Out:
# 'near%3A%22Broomfield%2C%20CO%22%20within%3A30mi'

# %%
api.GetSearch(term='#buildthewall beto',lang='en',result_type='popular')
# Out:
# [Status(ID=1095389042416500737, ScreenName=ACTforAmerica, Created=Tue Feb 12 18:27:53 +0000 2019, Text='Beto says walls are immoral yet he campaigns behind tall fencing. \n\nMakes you think!\n\n#BuildTheWall')]
